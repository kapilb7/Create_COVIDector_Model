# %%
import numpy as np
import pandas as pd
import os
import random 
from shutil import copyfile
import pydicom as dicom
import cv2

# %%
# set parameters here
savepath = '' #path to save the dataset
seed = 0
np.random.seed(seed) # Reset the seed so all runs are the same.
random.seed(seed)
MAXVAL = 255  # Range [0 255]

# path to covid-19 dataset from https://github.com/ieee8023/covid-chestxray-dataset
cohen_imgpath = '' 
cohen_csvpath = ''

# path to covid-19 dataset from https://github.com/agchung/Figure1-COVID-chestxray-dataset
fig1_imgpath = ''
fig1_csvpath = ''

# path to covid-19 dataset from https://github.com/agchung/Actualmed-COVID-chestxray-dataset
actmed_imgpath = ''
actmed_csvpath = ''

# path to covid-19 dataset from https://www.kaggle.com/tawsifurrahman/covid19-radiography-database
sirm_imgpath = ''
sirm_csvpath = ''

# path to https://www.kaggle.com/c/rsna-pneumonia-detection-challenge
rsna_datapath = ''
# get all the normal from here
rsna_csvname = '' 
# get all the 1s from here since 1 indicate pneumonia
# found that images that aren't pneunmonia and also not normal are classified as 0s
rsna_csvname2 = '' 
rsna_imgpath = ''

# parameters
train = []
test = []
test_count = {'negative': 0,'normal': 0, 'pneumonia': 0, 'COVID-19': 0}
train_count = {'negative': 0,'normal': 0, 'pneumonia': 0, 'COVID-19': 0}

mapping = dict()
mapping['COVID-19'] = 'COVID-19'
mapping['SARS'] = 'pneumonia'
mapping['MERS'] = 'pneumonia'
mapping['Streptococcus'] = 'pneumonia'
mapping['Klebsiella'] = 'pneumonia'
mapping['Chlamydophila'] = 'pneumonia'
mapping['Legionella'] = 'pneumonia'
mapping['E.Coli'] = 'pneumonia'
mapping['Normal'] = 'normal'
mapping['Lung Opacity'] = 'pneumonia'
mapping['1'] = 'pneumonia'

# train/test split
split = 0.1

# to avoid duplicates
patient_imgpath = {}

# %%
# adapted from https://github.com/mlmed/torchxrayvision/blob/master/torchxrayvision/datasets.py#L814
cohen_csv = pd.read_csv(cohen_csvpath, nrows=None)
#idx_pa = csv["view"] == "PA"  # Keep only the PA view
views = ["PA", "AP", "AP Supine", "AP semi erect", "AP erect"]
cohen_idx_keep = cohen_csv.view.isin(views)
cohen_csv = cohen_csv[cohen_idx_keep]

fig1_csv = pd.read_csv(fig1_csvpath, encoding='ISO-8859-1', nrows=None)
actmed_csv = pd.read_csv(actmed_csvpath, nrows=None)

sirm_csv = pd.read_excel(sirm_csvpath)

# %%
# get non-COVID19 viral, bacteria, and COVID-19 infections from covid-chestxray-dataset, figure1 and actualmed
# stored as patient id, image filename and label
filename_label = {'negative':[],'normal': [], 'pneumonia': [], 'COVID-19': []}
count = {'negative':0,'normal': 0, 'pneumonia': 0, 'COVID-19': 0}
covid_ds = {'cohen': [], 'fig1': [], 'actmed': [], 'sirm': []}

for index, row in cohen_csv.iterrows():
    f = row['finding'].split('/')[-1] # take final finding in hierarchy, for the case of COVID-19, ARDS
    if f in mapping: # 
        count[mapping[f]] += 1
        entry = [str(row['patientid']), row['filename'], mapping[f], 'cohen']
        filename_label[mapping[f]].append(entry)
        if mapping[f] == 'COVID-19':
            covid_ds['cohen'].append(str(row['patientid']))
    else:
        count['negative'] += 1
        entry = [str(row['patientid']), row['filename'], 'negative', 'cohen']
        filename_label['negative'].append(entry)
        
for index, row in fig1_csv.iterrows():
    if not str(row['finding']) == 'nan':
        f = row['finding'].split(',')[0] # take the first finding
        if f in mapping: # 
            count[mapping[f]] += 1
            if os.path.exists(os.path.join(fig1_imgpath, row['patientid'] + '.jpg')):
                entry = [row['patientid'], row['patientid'] + '.jpg', mapping[f], 'fig1']
            elif os.path.exists(os.path.join(fig1_imgpath, row['patientid'] + '.png')):
                entry = [row['patientid'], row['patientid'] + '.png', mapping[f], 'fig1']
            filename_label[mapping[f]].append(entry)
            if mapping[f] == 'COVID-19':
                covid_ds['fig1'].append(row['patientid'])

for index, row in actmed_csv.iterrows():
    if not str(row['finding']) == 'nan':
        f = row['finding'].split(',')[0]
        if f in mapping:
            count[mapping[f]] += 1
            entry = [row['patientid'], row['imagename'], mapping[f], 'actmed']
            filename_label[mapping[f]].append(entry)
            if mapping[f] == 'COVID-19':
                covid_ds['actmed'].append(row['patientid'])
        else:
            count['negative'] += 1
            entry = [row['patientid'], row['imagename'], 'negative', 'actmed']
            filename_label['negative'].append(entry)
    
sirm = set(sirm_csv['URL'])
cohen = set(cohen_csv['url'])
discard = ['100', '101', '102', '103', '104', '105', 
           '110', '111', '112', '113', '122', '123', 
           '124', '125', '126', '217']

for idx, row in sirm_csv.iterrows():
    patientid = row['FILE NAME']
    if row['URL'] not in cohen and patientid[patientid.find('(')+1:patientid.find(')')] not in discard:
        count[mapping['COVID-19']] += 1
        imagename = patientid + '.' + row['FORMAT'].lower()
        if not os.path.exists(os.path.join(sirm_imgpath, imagename)):
            imagename = "COVID ({}).png".format(imagename.rsplit(".png")[0].split("COVID ")[1])
        entry = [patientid, imagename, mapping['COVID-19'], 'sirm']
        filename_label[mapping['COVID-19']].append(entry)
        covid_ds['sirm'].append(patientid)
    
print('Data distribution from covid datasets:')
print(count)
# Out:
# Data distribution from covid datasets:
# {'negative': 373, 'normal': 0, 'pneumonia': 57, 'COVID-19': 1770}

# %%
# Create a random sample of 20 'negative' actmed patients to be added to the test set,
# the rest will be added to the train set
actmed_patients = []
duplicates = []

for entry in filename_label['negative']:
    if entry[3] == 'actmed':
        if entry[0] not in actmed_patients:
            actmed_patients.append(entry[0])
        else:
            duplicates.append(entry[0])

for num in duplicates:
    if num in actmed_patients:
        actmed_patients.remove(num)
    
test_patients_actmed = random.sample(actmed_patients, 20)

# %%
# add covid-chestxray-dataset, figure1 and actualmed into the dataset
# since these datasets don't have test dataset, split into train/test by patientid
# for covid-chestxray-dataset:
# patient 8 is used as non-COVID19 viral test
# patient 31 is used as bacterial test
# patients 19, 20, 36, 42, 86 are used as COVID-19 viral test
# for figure 1:
# patients 24, 25, 27, 29, 30, 32, 33, 36, 37, 38

ds_imgpath = {'cohen': cohen_imgpath, 'fig1': fig1_imgpath, 'actmed': actmed_imgpath, 'sirm': sirm_imgpath}

for key in filename_label.keys():
    arr = np.array(filename_label[key])
    if arr.size == 0:
        continue
    # split by patients
    num_diff_patients = len(np.unique(arr[:,0]))
    # num_test = max(1, round(split*num_diff_patients))
    # select num_test number of random patients
    # random.sample(list(arr[:,0]), num_test)
    if key == 'pneumonia':
        test_patients = ['8', '31']
    elif key == 'COVID-19':
        test_patients = ['19', '20', '36', '42', '86', 
                         '94', '97', '117', '132', 
                         '138', '144', '150', '163', '169', '174', '175', '179', '190', '191'
                         'COVID-00024', 'COVID-00025', 'COVID-00026', 'COVID-00027', 'COVID-00029',
                         'COVID-00030', 'COVID-00032', 'COVID-00033', 'COVID-00035', 'COVID-00036',
                         'COVID-00037', 'COVID-00038',
                         'ANON24', 'ANON45', 'ANON126', 'ANON106', 'ANON67',
                         'ANON153', 'ANON135', 'ANON44', 'ANON29', 'ANON201', 
                         'ANON191', 'ANON234', 'ANON110', 'ANON112', 'ANON73', 
                         'ANON220', 'ANON189', 'ANON30', 'ANON53', 'ANON46',
                         'ANON218', 'ANON240', 'ANON100', 'ANON237', 'ANON158',
                         'ANON174', 'ANON19', 'ANON195',
                         'COVID 119', 'COVID 87', 'COVID 70', 'COVID 94', 
                         'COVID 215', 'COVID 77', 'COVID 213', 'COVID 81', 
                         'COVID 216', 'COVID 72', 'COVID 106', 'COVID 131', 
                         'COVID 107', 'COVID 116', 'COVID 95', 'COVID 214', 
                         'COVID 129']
    elif key == 'negative':
        test_patients = test_patients_actmed
    else: 
        test_patients = []
    print('Key: ', key)
    print('Test patients: ', test_patients)
    # go through all the patients
    for patient in arr:
        if patient[0] not in patient_imgpath:
            patient_imgpath[patient[0]] = [patient[1]]
        else:
            if patient[1] not in patient_imgpath[patient[0]]:
                patient_imgpath[patient[0]].append(patient[1])
            else:
                continue  # skip since image has already been written
        if patient[0] in test_patients:
            if patient[3] == 'sirm':
                image = cv2.imread(os.path.join(ds_imgpath[patient[3]], patient[1]))
                gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
                patient[1] = patient[1].replace(' ', '')
                cv2.imwrite(os.path.join(savepath, 'test', patient[1]), gray)
            else:
                copyfile(os.path.join(ds_imgpath[patient[3]], patient[1]), os.path.join(savepath, 'test', patient[1]))
            test.append(patient)
            test_count[patient[2]] += 1
        else:
            if patient[3] == 'sirm':
                image = cv2.imread(os.path.join(ds_imgpath[patient[3]], patient[1]))
                gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
                patient[1] = patient[1].replace(' ', '')
                cv2.imwrite(os.path.join(savepath, 'train', patient[1]), gray)
            else:
                copyfile(os.path.join(ds_imgpath[patient[3]], patient[1]), os.path.join(savepath, 'train', patient[1]))
            train.append(patient)
            train_count[patient[2]] += 1

print('test count: ', test_count)
print('train count: ', train_count)
# Out:
# Key:  negative
# Test patients:  ['ANON148', 'ANON6', 'ANON152', 'ANON93', 'ANON2', 'ANON193', 'ANON156', 'ANON28', 'ANON143', 'ANON186', 'ANON15', 'ANON65', 'ANON128', 'ANON168', 'ANON120', 'ANON194', 'ANON216', 'ANON131', 'ANON175', 'ANON141']
# Key:  pneumonia
# Test patients:  ['8', '31']
# Key:  COVID-19
# Test patients:  ['19', '20', '36', '42', '86', '94', '97', '117', '132', '138', '144', '150', '163', '169', '174', '175', '179', '190', '191COVID-00024', 'COVID-00025', 'COVID-00026', 'COVID-00027', 'COVID-00029', 'COVID-00030', 'COVID-00032', 'COVID-00033', 'COVID-00035', 'COVID-00036', 'COVID-00037', 'COVID-00038', 'ANON24', 'ANON45', 'ANON126', 'ANON106', 'ANON67', 'ANON153', 'ANON135', 'ANON44', 'ANON29', 'ANON201', 'ANON191', 'ANON234', 'ANON110', 'ANON112', 'ANON73', 'ANON220', 'ANON189', 'ANON30', 'ANON53', 'ANON46', 'ANON218', 'ANON240', 'ANON100', 'ANON237', 'ANON158', 'ANON174', 'ANON19', 'ANON195', 'COVID 119', 'COVID 87', 'COVID 70', 'COVID 94', 'COVID 215', 'COVID 77', 'COVID 213', 'COVID 81', 'COVID 216', 'COVID 72', 'COVID 106', 'COVID 131', 'COVID 107', 'COVID 116', 'COVID 95', 'COVID 214', 'COVID 129']
# test count:  {'negative': 20, 'normal': 0, 'pneumonia': 5, 'COVID-19': 100}
# train count:  {'negative': 353, 'normal': 0, 'pneumonia': 52, 'COVID-19': 1670}

# %%
# add normal and rest of pneumonia cases from https://www.kaggle.com/c/rsna-pneumonia-detection-challenge
csv_normal = pd.read_csv(os.path.join(rsna_datapath, rsna_csvname), nrows=None)
csv_pneu = pd.read_csv(os.path.join(rsna_datapath, rsna_csvname2), nrows=None)
patients = {'normal': [], 'pneumonia': []}

for index, row in csv_normal.iterrows():
    if row['class'] == 'Normal':
        patients['normal'].append(row['patientId'])

for index, row in csv_pneu.iterrows():
    if int(row['Target']) == 1:
        patients['pneumonia'].append(row['patientId'])

for key in patients.keys():
    arr = np.array(patients[key])
    if arr.size == 0:
        continue
    # split by patients 
    num_diff_patients = len(np.unique(arr))
    # num_test = max(1, round(split*num_diff_patients))
    test_patients = np.load('path until here/rsna-pneumonia-detection-challenge/rsna_test_patients_{}.npy'.format(key)) # random.sample(list(arr), num_test), download the .npy files from the repo.
    # np.save('rsna_test_patients_{}.npy'.format(key), np.array(test_patients))
    for patient in arr:
        if patient not in patient_imgpath:
            patient_imgpath[patient] = [patient]
        else:
            continue  # skip since image has already been written
                
        ds = dicom.dcmread(os.path.join(rsna_datapath, rsna_imgpath, patient + '.dcm'))
        pixel_array_numpy = ds.pixel_array
        imgname = patient + '.png'
        if patient in test_patients:
            cv2.imwrite(os.path.join(savepath, 'test', imgname), pixel_array_numpy)
            test.append([patient, imgname, key, 'rsna'])
            test_count[key] += 1
        else:
            cv2.imwrite(os.path.join(savepath, 'train', imgname), pixel_array_numpy)
            train.append([patient, imgname, key, 'rsna'])
            train_count[key] += 1

print('test count: ', test_count)
print('train count: ', train_count)
# Out:
# test count:  {'negative': 20, 'normal': 885, 'pneumonia': 594, 'COVID-19': 100}
# train count:  {'negative': 353, 'normal': 7966, 'pneumonia': 5475, 'COVID-19': 1670}

# %%
# final stats
print('Final stats')
print('Train count: ', train_count)
print('Test count: ', test_count)
print('Total length of train: ', len(train))
print('Total length of test: ', len(test))
# Out:
# Final stats
# Train count:  {'negative': 353, 'normal': 7966, 'pneumonia': 5475, 'COVID-19': 1670}
# Test count:  {'negative': 20, 'normal': 885, 'pneumonia': 594, 'COVID-19': 100}
# Total length of train:  15464
# Total length of test:  1599

# %%
# Create a test set containing the 100 COVID-19 test samples and a random selection of 
# 10 normal cases, 70 pneumonia cases, and 20 negative cases from Actuamed
final_test = []

normal_cases = []
pneumonia_cases = []

for entry in test:
    if entry[3] == 'actmed' and entry[2] == 'negative':
        final_test.append(entry)
    if entry[2] == 'pneumonia':
        pneumonia_cases.append(entry)
    if entry[2] == 'normal':
        normal_cases.append(entry)
    if entry[2] == 'COVID-19':
        final_test.append(entry)

final_test = final_test + random.sample(normal_cases, 10) + random.sample(pneumonia_cases, 70)
print('Length of final test set : ', len(final_test))
# Out:
# Length of final test set :  200

# %%
train
# Out:
# [array(['5', 'ARDSSevere.png', 'negative', 'cohen'], dtype='<U67'),
#  array(['25', 'acute-respiratory-distress-syndrome-ards-1.jpg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['26', 'acute-respiratory-distress-syndrome-ards.jpg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['27', 'ards-secondary-to-tiger-snake-bite.png', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['28', 'pneumocystis-pneumonia-2-PA.png', 'negative', 'cohen'],
#        dtype='<U67'),
#  array(['38', 'F051E018-DAD1-4506-AD43-BE4CA29E960B.jpeg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['101', 'pneumocystis-jirovecii-pneumonia-3-1.jpg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['101', 'pneumocystis-jirovecii-pneumonia-3-2.jpg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['101', 'pneumocystis-jirovecii-pneumonia-3-3.jpg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['102', 'pneumocystis-pneumonia-1.jpg', 'negative', 'cohen'],
#        dtype='<U67'),
#  array(['103', 'X-ray_of_cyst_in_pneumocystis_pneumonia_1.jpg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['104', 'pneumocystis-pneumonia-8.jpg', 'negative', 'cohen'],
#        dtype='<U67'),
#  array(['105', 'pneumocystis-carinii-pneumonia-1-PA.jpg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['106', 'pneumocystis-pneumonia-12.png', 'negative', 'cohen'],
#        dtype='<U67'),
#  array(['107', 'pneumocystis-jiroveci-pneumonia-2.png', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['108', 'pneumocystis-jirovecii-pneumonia-2.jpg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['109', 'pneumocystis-jiroveci-pneumonia-4-PA.png', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['173', 'covid-19-pneumonia-58-prior.jpg', 'negative', 'cohen'],
#        dtype='<U67'),
#  array(['210', '16745_2_1.PNG', 'negative', 'cohen'], dtype='<U67'),
#  array(['211', '16745_3_1.png', 'negative', 'cohen'], dtype='<U67'),
#  array(['214', '16745_6_1.png', 'negative', 'cohen'], dtype='<U67'),
#  array(['221', 'a4318ac9.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['251', '2c35005f.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['253', 'ada8c494.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['272', '16583_1_1.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['272', '16583_3_1.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['273', '000001-2.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['276', '000005-5-a.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['277', '000005-3.png', 'negative', 'cohen'], dtype='<U67'),
#  array(['277', '000006-2.png', 'negative', 'cohen'], dtype='<U67'),
#  array(['277', '000007-2.png', 'negative', 'cohen'], dtype='<U67'),
#  array(['277', '000010-2.png', 'negative', 'cohen'], dtype='<U67'),
#  array(['278', '000001-9-a.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['278', '000002-11-a.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['279', '000001-3.png', 'negative', 'cohen'], dtype='<U67'),
#  array(['279', '000002-4.png', 'negative', 'cohen'], dtype='<U67'),
#  array(['279', '000003-4.png', 'negative', 'cohen'], dtype='<U67'),
#  array(['279', '000004-3.png', 'negative', 'cohen'], dtype='<U67'),
#  array(['281', '000001-12.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['282', '000001.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['282', '000008-8.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['282', '000016.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['282', '000024-1.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['283', '000001-17.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['283', '000002-19-a.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['286', '000001-6.png', 'negative', 'cohen'], dtype='<U67'),
#  array(['313b', '10.1016-slash-j.hrcr.2020.04.015-fig3-a.png', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['315', '1-s2.0-S2214250920300834-gr1_lrg-d.png', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['316', '1-s2.0-S2213716520301168-gr1_lrg-c.png', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['318', '1-s2.0-S1341321X20301124-gr3_lrg-a.png', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['318', '1-s2.0-S1341321X20301124-gr3_lrg-b.png', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['325', '1-s2.0-S1059131120301151-gr2-e.png', 'negative', 'cohen'],
#        dtype='<U67'),
#  array(['339', '000001-24.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['339', '000006-17.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['339', '000007-15.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['351', '665f7ed5dcf52f235d8abed8cc200c_jumbo.jpeg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['360b', '5f8aaa4e85af075412849ebf8ebb54_jumbo-1.jpg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['360b', '13cd850b02d1afe48c113a73eed882_jumbo-1.jpg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['360b', 'b50c02b92f2b98f5e1477ff759ce94_jumbo-1.jpg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['360b', '94c6945194a265ae1301bec234a7e0_jumbo-1.jpg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['360b', '52a8b6bf730b648d37b37d2aa51fd3_jumbo-1.jpg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['361a', '4e1dc09c3abe03a3efb72d494ddb6f_jumbo-2.jpeg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['361b', '9a4e0141fd7681c4026b55b4e13914_jumbo-2.jpeg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['362', 'e9cc806fc1c90195d999dc8d022d28_jumbo-2.jpeg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['362', 'bb25b35e1cc5cb0984ead37363db0e_jumbo-2.jpeg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['364', '582f068ae16494e015cf2b2ed90388_jumbo-1.jpeg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['364', '3d4364c0e44859e86017ee1660112e_jumbo-1.jpeg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['365', '487354e56da5b0363458d0297446f0_jumbo-1.jpeg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['365', '946b48f8564d681eb8950ea8a659e0_jumbo-1.jpeg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['366', 'f410057190635755d60158d1595d67_jumbo-1.jpeg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['367', '56bc74129531580d3c40b1f8ae77ab_jumbo.jpeg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['368', 'd84789f9ece74ea65e7ec2c4faaaf3_jumbo.jpeg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['368', '981f82325fcc645a78a1732ab783f1_jumbo.jpeg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['369', '26eecee1e498237cc3ea3274b79ff0_jumbo.jpg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['369', '21f0cfca1c3d5d11e9eb8f6c670f73_jumbo.jpg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['369', 'b85b6449f7c3bfc841a973cca0ada7_jumbo.jpg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['370', 'f72b17e863d0f958b65379b3669238_jumbo.jpg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['371', '19876b357ac5c998a06d9614b6148a_jumbo.jpeg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['372', '22ebbc464e16ea1217228e3c9f4935_jumbo.jpeg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['373', 'cdf5605e45874c28262c81b7ab80b3_jumbo.jpeg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['374', '82cb30b7678c6da229c6dc222c39c9_jumbo.jpeg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['375', '84da526d0453b9b9e7896631e6b366_jumbo.jpeg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['376', '503d2fbe68cd143b0f15749b4f816b_jumbo.jpeg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['377', 'a24181c437aca166f7aeccc62ba28a_jumbo.jpg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['379', '1e64990d1b40c1758a2aaa9c7f7a85_jumbo.jpeg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['379', '7223b8ad031187d9a142d7f7ca02c9_jumbo.jpeg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['380', '3392dc7d262e28423caca517f98c2e_jumbo.jpeg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['380', 'ec3a480c0926ded74429df416cfb05_jumbo.jpeg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['381', '076d9f1ab85d17bcf0f4f207891974_jumbo.jpg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['382', 'a72aeb349a63c79ed24e473c434efe_jumbo.jpg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['382', 'ba45a47c3ef5060ec39891046be7ca_jumbo.jpg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['383', '6f36c4ad54047bc52b38fd8c9d1e22_jumbo.jpg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['383', '621f53af15cf08e6e13cb6812eead9_jumbo.jpg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['384', '6646071b.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['385', '5359825d.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['386', '0cd9fcb6.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['386', 'ce09cfab.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['386', 'b0500187.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['387', '40f355ec.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['387', 'e6eaadf0.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['387', '34d999a9.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['387', 'fbb18dc0.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['388', '54d57e77.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['388', 'a7e0a141.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['388', 'd806f9a1.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['389', '19a01707.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['389', 'bf551b8b.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['389', '1e534853.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['389', 'aa9655de.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['389', '073a8f93.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['389', '7a9ec606.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['390', '88859dc1.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['391', '3a81faf3.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['391', 'bcb814aa.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['392', '76093afc.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['393', '000012.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['394', '16755_1_1.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['395', '000001-1.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['397', '000001-3.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['397', '000003-1.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['398', '000003-2.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['399', '000001-4.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['399', '000002-3.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['399', '000003-3.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['402', '000001-6.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['402', '000002-4.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['403', '000001-7.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['403', '000003-4.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['404', '000001-8.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['404', '000002-5.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['405', '000001-9.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['406', '000001-10.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['407', '000001-11.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['408', '000001-13.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['410', '000001.png', 'negative', 'cohen'], dtype='<U67'),
#  array(['410', '000007.png', 'negative', 'cohen'], dtype='<U67'),
#  array(['411', '16497_1_1.png', 'negative', 'cohen'], dtype='<U67'),
#  array(['412', '000001-14.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['412', '000002-6.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['413', '000001-15.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['413', '000002-7.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['413', '000003-5.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['415', 'untitled.001_0.jpeg', 'negative', 'cohen'], dtype='<U67'),
#  array(['416', '000001-1.png', 'negative', 'cohen'], dtype='<U67'),
#  array(['416', '000003-6.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['417', '000001-4.png', 'negative', 'cohen'], dtype='<U67'),
#  array(['418', '000001-18.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['419', '000010.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['420', '000001-20.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['420', '000005-1.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['420', '000007.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['420', '000012-1.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['421', '000001-5.png', 'negative', 'cohen'], dtype='<U67'),
#  array(['423a', 'MERS-CoV-1-s2.0-S0378603X1500248X-gr4e.jpg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['423b', '1-s2.0-S0378603X1500248X-gr2a.jpg', 'negative', 'cohen'],
#        dtype='<U67'),
#  array(['423b', '1-s2.0-S0378603X1500248X-gr2b.jpg', 'negative', 'cohen'],
#        dtype='<U67'),
#  array(['423b', '1-s2.0-S0378603X1500248X-gr2c.jpg', 'negative', 'cohen'],
#        dtype='<U67'),
#  array(['423b', '1-s2.0-S0378603X1500248X-gr2d.jpg', 'negative', 'cohen'],
#        dtype='<U67'),
#  array(['425c', '1-s2.0-S0378603X1500248X-gr3a.jpg', 'negative', 'cohen'],
#        dtype='<U67'),
#  array(['425c', '1-s2.0-S0378603X1500248X-gr3b.jpg', 'negative', 'cohen'],
#        dtype='<U67'),
#  array(['425c', '1-s2.0-S0378603X1500248X-gr3d.jpg', 'negative', 'cohen'],
#        dtype='<U67'),
#  array(['425d', '1-s2.0-S0378603X1500248X-gr4a.jpg', 'negative', 'cohen'],
#        dtype='<U67'),
#  array(['425d', '1-s2.0-S0378603X1500248X-gr4c.jpg', 'negative', 'cohen'],
#        dtype='<U67'),
#  array(['425d', '1-s2.0-S0378603X1500248X-gr4e.jpg', 'negative', 'cohen'],
#        dtype='<U67'),
#  array(['429', 'fff13f3a.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['430', 'c4a0e11a.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['430', '33ad0dcb.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['430', '26e8db49.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['430', 'd2af569b.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['430', '2ecd360d.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['431', '26b79d0d.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['431', '2086b9e1.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['431', '3309d07c.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['431', '341e2287.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['431', '0ac7580d.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['431', '86ee6e6c.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['431', 'b03ef875.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['431', 'f875007a.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['431', 'cb60786c.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['432', '1d40779e.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['432', '0cea09eb.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['433', '27a70642.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['433', 'e53ea41a.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['433', 'ce68550a.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['434', '2fdd55b8.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['434', 'f722466f.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['435', '3964b961.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['435', '7b68340a.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['435', '90c1e3ef.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['435', '0957ce54.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['436', 'cfcdf8d9.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['436', '24de8686.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['436', 'a228e110.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['436', 'd2c83bde.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['436', '78af4c1d.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['436', '85540916.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['436', 'a8685b98.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['436', '09258248.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['436', '1e33b16c.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['436', '430f21e7.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['436', '587e7c1a.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['436', '98c24e39.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['436', '7940dea2.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['436', 'f0a93ef2.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['436', '183af0d0.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['436', '4b907d01.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['436', '40f67745.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['436', '242a639e.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['436', 'e104f46d.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['436', '15d945b8.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['436', 'ba040c5e.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['436', 'b37c225f.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['437', '23823ebc.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['437', 'e87352fc.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['438', '27f5a41d.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['439', '006f3a8a.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['440', '1d6c4b7c.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['441', '18017511.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['442', '689836b5.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['443', '1ae7877e.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['444', '5f001e0b.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['444', 'e9877113.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['444', 'c873402e.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['444', '5b324cc7.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['449', '7185bd4a8cc3280902117d034c7653_jumbo.jpg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['451', '75fb7cd80d5ca4074c474f93471ad4_jumbo.jpeg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['451', '01ec02c48ce0120d57456b2ee2d02f_jumbo.jpeg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['452', 'd815245ec98b5f0efc73b89daef72c_jumbo.jpg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['453', '616f829f195d0cd856616586c7c35e_jumbo.jpeg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['454', '71b364138ea4986831b3778081cd2e_jumbo.jpeg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['456', 'ffad3e6c27fe36031249c81647800f_jumbo.jpeg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['457', 'b2f42e0cdfcbe32f189eb467b05e24_jumbo.jpg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['460', '8f46c8ad3d40a93b4a313f15092e1d_jumbo.jpeg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['461', 'bc370d0566b31259c2d9544748eb21_jumbo.jpeg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['464', '8b7aeaa2063bf9a12ed6b79c173f4e_jumbo.jpeg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['466', '1538fbfe9d0872739b00f5a51e4fdc_jumbo.jpeg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['467', '7a7044c64a87936f09fee9a7f5c5fa_jumbo.jpeg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['468', '4e74cbafeab0bfd317a93e1aace6cf_jumbo.jpg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['469', '2264f643b18b1010ec10a850f17550_jumbo.jpeg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['470', '55f5189d2c23688ac8dc1d58eb65cf_jumbo.jpg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['478', '02b973e10caa192fd4e6825ad4aeaf_jumbo-10.jpeg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['478', 'd2c8a74b37d8d1581ea2a8fe865ef3_jumbo-10.jpeg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['479', '072ecaf8c60a81980abb57150a8016_jumbo-9.jpeg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['479', 'ff33c406392b968d483174c97eb857_jumbo-9.jpeg', 'negative',
#         'cohen'], dtype='<U67'),
#  array(['480', '000001-266.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['481', '000001-272.jpg', 'negative', 'cohen'], dtype='<U67'),
#  array(['ANON56',
#         'CR.1.2.840.113564.1722810170.20200317090830828260.1003000225002.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON56',
#         'CR.1.2.840.113564.1722810170.20200317104341875470.1003000225002.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON91',
#         'CR.1.2.840.113564.1722810170.20200319202613984410.1003000225002.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON245',
#         'CR.1.2.840.113564.1722810170.20200323115834968210.1003000225002.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON239',
#         'CR.1.2.840.113564.1722810170.202003241816485934.1003000225002.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON58',
#         'CR.1.2.840.113564.1722810170.20200401171818781600.1003000225002.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON235',
#         'CR.1.2.840.113564.1722810170.20200403010103781780.1003000225002.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON167',
#         'CR.1.2.840.113564.192168196.2020031913094890017.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON191',
#         'CR.1.2.840.113564.192168196.2020031913311637123.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON224',
#         'CR.1.2.840.113564.192168196.2020031914133530635.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON1',
#         'CR.1.2.840.113564.192168196.2020031914434008949.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON83',
#         'CR.1.2.840.113564.192168196.2020032008575844669.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON83',
#         'CR.1.2.840.113564.192168196.2020032009002413573.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON99',
#         'CR.1.2.840.113564.192168196.2020032009520943077.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON22',
#         'CR.1.2.840.113564.192168196.2020032413222814777.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON134',
#         'CR.1.2.840.113564.192168196.2020032712415994976.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON121',
#         'CR.1.2.840.113564.192168196.2020033016123149069.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON211',
#         'CR.1.2.840.113564.192168196.2020033115253391026.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON155',
#         'CR.1.2.840.113564.192168196.2020040117583329780.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON40',
#         'CR.1.2.840.113564.192168196.2020040314541260251.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON178',
#         'CR.1.2.840.113564.192168196.2020040708262888222.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON219',
#         'CR.1.2.840.113564.192168196.2020041316410681120.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON86',
#         'DX.1.2.840.113564.1722810162.20200320112920531100.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON162',
#         'DX.1.2.840.113564.1722810162.20200320114116138220.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON49',
#         'DX.1.2.840.113564.1722810162.20200320150341771440.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON55',
#         'DX.1.2.840.113564.1722810162.20200320155115417540.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON213',
#         'DX.1.2.840.113564.1722810162.20200320175830093580.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON48',
#         'DX.1.2.840.113564.1722810162.20200321085646975740.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON179',
#         'DX.1.2.840.113564.1722810162.20200321114314263800.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON207',
#         'DX.1.2.840.113564.1722810162.20200321204028829980.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON109',
#         'DX.1.2.840.113564.1722810162.202003212127446125.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON95',
#         'DX.1.2.840.113564.1722810162.20200322012248568150.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON145',
#         'DX.1.2.840.113564.1722810162.20200322143316916570.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON173',
#         'DX.1.2.840.113564.1722810162.20200323104202808100.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON56',
#         'DX.1.2.840.113564.1722810162.20200323113158393220.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON243',
#         'DX.1.2.840.113564.1722810162.20200324140423562310.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON17',
#         'DX.1.2.840.113564.1722810162.20200324163640450390.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON5',
#         'DX.1.2.840.113564.1722810162.20200324173713500510.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON96',
#         'DX.1.2.840.113564.1722810162.202003251249284366.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON54',
#         'DX.1.2.840.113564.1722810162.20200325130434611240.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON97',
#         'DX.1.2.840.113564.1722810162.20200325133712872360.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON125',
#         'DX.1.2.840.113564.1722810162.20200325160609990420.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON52',
#         'DX.1.2.840.113564.1722810162.20200325180041010540.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON229',
#         'DX.1.2.840.113564.1722810162.20200325180923403640.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON62',
#         'DX.1.2.840.113564.1722810162.20200326103306090980.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON81',
#         'DX.1.2.840.113564.1722810162.20200327115150971770.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON182',
#         'DX.1.2.840.113564.1722810162.20200327130648390830.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON137',
#         'DX.1.2.840.113564.1722810162.20200327135950280950.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON75',
#         'DX.1.2.840.113564.1722810162.20200328130557219720.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON166',
#         'DX.1.2.840.113564.1722810162.20200330101715842390.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON171',
#         'DX.1.2.840.113564.1722810162.20200330115928823450.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON13',
#         'DX.1.2.840.113564.1722810162.20200330142125620570.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON11',
#         'DX.1.2.840.113564.1722810162.20200330155549529100.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON163',
#         'DX.1.2.840.113564.1722810162.20200331093347514180.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON35',
#         'DX.1.2.840.113564.1722810162.20200331165352707460.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON198',
#         'DX.1.2.840.113564.1722810162.20200331235358718640.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON71',
#         'DX.1.2.840.113564.1722810162.20200401095800552100.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON183',
#         'DX.1.2.840.113564.1722810162.20200403103712240360.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON60',
#         'DX.1.2.840.113564.1722810162.20200403105318208480.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON206',
#         'DX.1.2.840.113564.1722810162.20200403113227763540.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON35',
#         'DX.1.2.840.113564.1722810162.20200404145807490420.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON10',
#         'DX.1.2.840.113564.1722810162.20200404194854145480.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON59',
#         'DX.1.2.840.113564.1722810162.20200404203720370540.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON18',
#         'DX.1.2.840.113564.1722810162.20200404210401196600.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON242',
#         'DX.1.2.840.113564.1722810162.20200405000323941660.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON206',
#         'DX.1.2.840.113564.1722810162.20200405214257011250.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON105',
#         'DX.1.2.840.113564.1722810162.20200406082745416370.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON221',
#         'DX.1.2.840.113564.1722810162.20200406152138599630.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON238',
#         'DX.1.2.840.113564.1722810162.20200407095712184770.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON90',
#         'DX.1.2.840.113564.1722810162.20200407110159061830.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON165',
#         'DX.1.2.840.113564.1722810162.20200407154351156930.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON43',
#         'DX.1.2.840.113564.1722810162.20200408152416905270.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON60',
#         'DX.1.2.840.113564.1722810162.20200408170334886370.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON190',
#         'DX.1.2.840.113564.1722810162.20200409100734996750.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON140',
#         'DX.1.2.840.113564.1722810162.20200409131002213950.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON124',
#         'DX.1.2.840.113564.1722810162.20200410122807096300.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON59',
#         'DX.1.2.840.113564.1722810162.20200410172247966360.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON113',
#         'DX.1.2.840.113564.1722810162.20200410175512031420.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON146',
#         'DX.1.2.840.113564.1722810162.20200413144300534160.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON20',
#         'DX.1.2.840.113564.1722810162.20200413163143169320.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON12',
#         'DX.1.2.840.113564.1722810162.20200414101717389720.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON37',
#         'DX.1.2.840.113564.1722810162.20200414150507492960.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON205',
#         'DX.1.2.840.113564.1722810162.202004141559081673.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON208',
#         'DX.1.2.840.113564.1722810162.20200414192734848390.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON79',
#         'DX.1.2.840.113564.1722810162.20200414235332189450.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON74',
#         'DX.1.2.840.113564.1722810162.20200415172911278870.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON129',
#         'DX.1.2.840.113564.1722810162.20200416083007099140.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON130',
#         'DX.1.2.840.113564.1722810162.20200416130101712300.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON21',
#         'DX.1.2.840.113564.1722810162.20200416135234642360.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON51',
#         'DX.1.2.840.113564.1722810162.20200416190453105480.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON161',
#         'DX.1.2.840.113564.1722810162.20200416191632203540.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON104',
#         'DX.1.2.840.113564.1722810162.20200417024634079600.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON228',
#         'DX.1.2.840.113564.1722810162.20200417102240621720.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON149',
#         'DX.1.2.840.113564.1722810162.20200417105359936840.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON151',
#         'DX.1.2.840.113564.1722810162.20200417110000959900.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON122',
#         'DX.1.2.840.113564.1722810162.202004171314057425.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON185',
#         'DX.1.2.840.113564.1722810162.20200417134736990110.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON180',
#         'DX.1.2.840.113564.1722810162.20200417201319616230.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON115',
#         'DX.1.2.840.113564.1722810162.20200417214150749290.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON154',
#         'DX.1.2.840.113564.1722810162.20200418123953240490.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON98',
#         'DX.1.2.840.113564.1722810162.20200418170644187730.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON118',
#         'DX.1.2.840.113564.1722810162.20200419111851705930.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON233',
#         'DX.1.2.840.113564.1722810162.20200420123349689300.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON192',
#         'DX.1.2.840.113564.1722810162.20200420140206725640.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON187',
#         'DX.1.2.840.113564.1722810162.20200420150441592700.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON33',
#         'DX.1.2.840.113564.1722810162.20200420155936364760.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON41',
#         'DX.1.2.840.113564.1722810162.20200420164750991860.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['3', 'SARS-10.1148rg.242035193-g04mr34g0-Fig8a-day0.jpeg',
#         'pneumonia', 'cohen'], dtype='<U64'),
#  array(['3', 'SARS-10.1148rg.242035193-g04mr34g0-Fig8b-day5.jpeg',
#         'pneumonia', 'cohen'], dtype='<U64'),
#  array(['3', 'SARS-10.1148rg.242035193-g04mr34g0-Fig8c-day10.jpeg',
#         'pneumonia', 'cohen'], dtype='<U64'),
#  array(['7', 'SARS-10.1148rg.242035193-g04mr34g04a-Fig4a-day7.jpeg',
#         'pneumonia', 'cohen'], dtype='<U64'),
#  array(['7', 'SARS-10.1148rg.242035193-g04mr34g04b-Fig4b-day12.jpeg',
#         'pneumonia', 'cohen'], dtype='<U64'),
#  array(['9', 'SARS-10.1148rg.242035193-g04mr34g07a-Fig7a-day5.jpeg',
#         'pneumonia', 'cohen'], dtype='<U64'),
#  array(['9', 'SARS-10.1148rg.242035193-g04mr34g07b-Fig7b-day12.jpeg',
#         'pneumonia', 'cohen'], dtype='<U64'),
#  array(['10', 'SARS-10.1148rg.242035193-g04mr34g09a-Fig9a-day17.jpeg',
#         'pneumonia', 'cohen'], dtype='<U64'),
#  array(['10', 'SARS-10.1148rg.242035193-g04mr34g09b-Fig9b-day19.jpeg',
#         'pneumonia', 'cohen'], dtype='<U64'),
#  array(['10', 'SARS-10.1148rg.242035193-g04mr34g09c-Fig9c-day27.jpeg',
#         'pneumonia', 'cohen'], dtype='<U64'),
#  array(['29', 'streptococcus-pneumoniae-pneumonia-1.jpg', 'pneumonia',
#         'cohen'], dtype='<U64'),
#  array(['30', 'pneumonia-7.jpg', 'pneumonia', 'cohen'], dtype='<U64'),
#  array(['87', 'pneumococcal-pneumonia-day0.jpg', 'pneumonia', 'cohen'],
#        dtype='<U64'),
#  array(['87', 'pneumococcal-pneumonia-day7.jpg', 'pneumonia', 'cohen'],
#        dtype='<U64'),
#  array(['87', 'pneumococcal-pneumonia-day35.jpg', 'pneumonia', 'cohen'],
#        dtype='<U64'),
#  array(['88', 'parapneumonic-effusion-1-PA.png', 'pneumonia', 'cohen'],
#        dtype='<U64'),
#  array(['89', 'right-upper-lobe-pneumonia-9-PA.jpg', 'pneumonia', 'cohen'],
#        dtype='<U64'),
#  array(['90', 'chlamydia-pneumonia-PA.png', 'pneumonia', 'cohen'],
#        dtype='<U64'),
#  array(['91', 'aspiration-pneumonia-5-day0.jpg', 'pneumonia', 'cohen'],
#        dtype='<U64'),
#  array(['91', 'aspiration-pneumonia-5-day3.jpg', 'pneumonia', 'cohen'],
#        dtype='<U64'),
#  array(['91', 'aspiration-pneumonia-5-day10.jpg', 'pneumonia', 'cohen'],
#        dtype='<U64'),
#  array(['91', 'aspiration-pneumonia-5-day27.jpg', 'pneumonia', 'cohen'],
#        dtype='<U64'),
#  array(['92', 'cavitating-pneumonia-4-day0-PA.jpg', 'pneumonia', 'cohen'],
#        dtype='<U64'),
#  array(['92', 'cavitating-pneumonia-4-day28-PA.png', 'pneumonia', 'cohen'],
#        dtype='<U64'),
#  array(['100', 'klebsiella-pneumonia-1.jpg', 'pneumonia', 'cohen'],
#        dtype='<U64'),
#  array(['110', 'legionella-pneumonia-1.png', 'pneumonia', 'cohen'],
#        dtype='<U64'),
#  array(['111', 'legionella-pneumonia-2.jpg', 'pneumonia', 'cohen'],
#        dtype='<U64'),
#  array(['170', 'wong-0000.jpg', 'pneumonia', 'cohen'], dtype='<U64'),
#  array(['171', 'wong-0002.jpg', 'pneumonia', 'cohen'], dtype='<U64'),
#  array(['171', 'wong-0003.jpg', 'pneumonia', 'cohen'], dtype='<U64'),
#  array(['171', 'wong-0004.jpg', 'pneumonia', 'cohen'], dtype='<U64'),
#  array(['172', 'wong-0005.jpg', 'pneumonia', 'cohen'], dtype='<U64'),
#  array(['271', '16646_1_1.jpg', 'pneumonia', 'cohen'], dtype='<U64'),
#  array(['284', '000001-19.jpg', 'pneumonia', 'cohen'], dtype='<U64'),
#  array(['284', '000006-12.jpg', 'pneumonia', 'cohen'], dtype='<U64'),
#  array(['284', '000010-5.jpg', 'pneumonia', 'cohen'], dtype='<U64'),
#  array(['284', '000011-6.jpg', 'pneumonia', 'cohen'], dtype='<U64'),
#  array(['284', '000012-3.jpg', 'pneumonia', 'cohen'], dtype='<U64'),
#  array(['340', '000001-27.jpg', 'pneumonia', 'cohen'], dtype='<U64'),
#  array(['363', 'f6ece95b172eadba762bf3daef7441_jumbo-1.jpeg', 'pneumonia',
#         'cohen'], dtype='<U64'),
#  array(['396', '000004.jpg', 'pneumonia', 'cohen'], dtype='<U64'),
#  array(['396', '000005.jpg', 'pneumonia', 'cohen'], dtype='<U64'),
#  array(['396', '000003.jpg', 'pneumonia', 'cohen'], dtype='<U64'),
#  array(['409', '000004.png', 'pneumonia', 'cohen'], dtype='<U64'),
#  array(['450', '4c8dee3d9fe81567b98ed1b0b2b4c6_jumbo.JPG', 'pneumonia',
#         'cohen'], dtype='<U64'),
#  array(['462', '3e9d9c9b02b9bcd81c851134667e76_jumbo.jpg', 'pneumonia',
#         'cohen'], dtype='<U64'),
#  array(['462', '2fc8a7c61c76f13ee7f9306b44e792_jumbo.jpg', 'pneumonia',
#         'cohen'], dtype='<U64'),
#  array(['462', '92d755fba55c3305419b5cac83fbf5_jumbo.jpg', 'pneumonia',
#         'cohen'], dtype='<U64'),
#  array(['462', '6ffc98957c18d4e3f2da8da48105e3_jumbo.jpg', 'pneumonia',
#         'cohen'], dtype='<U64'),
#  array(['463', 'dc025523f07c043550a2c9de68ae50_jumbo.jpeg', 'pneumonia',
#         'cohen'], dtype='<U64'),
#  array(['477', 'bdc40f9ad2395d88c92479089f5d1b_jumbo-10.jpeg', 'pneumonia',
#         'cohen'], dtype='<U64'),
#  array(['477', '15d081345df9ca620ebe5e76023775_jumbo-10.jpeg', 'pneumonia',
#         'cohen'], dtype='<U64'),
#  array(['2',
#         'auntminnie-a-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg',
#         'COVID-19', 'cohen'], dtype='<U91'),
#  array(['2',
#         'auntminnie-b-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg',
#         'COVID-19', 'cohen'], dtype='<U91'),
#  array(['2',
#         'auntminnie-c-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg',
#         'COVID-19', 'cohen'], dtype='<U91'),
#  array(['2',
#         'auntminnie-d-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg',
#         'COVID-19', 'cohen'], dtype='<U91'),
#  array(['4', 'nejmc2001573_f1a.jpeg', 'COVID-19', 'cohen'], dtype='<U91'),
#  array(['4', 'nejmc2001573_f1b.jpeg', 'COVID-19', 'cohen'], dtype='<U91'),
#  array(['6', 'lancet-case2a.jpg', 'COVID-19', 'cohen'], dtype='<U91'),
#  array(['6', 'lancet-case2b.jpg', 'COVID-19', 'cohen'], dtype='<U91'),
#  array(['11', '1-s2.0-S0140673620303706-fx1_lrg.jpg', 'COVID-19', 'cohen'],
#        dtype='<U91'),
#  array(['12', 'nCoV-radiol.2020200269.fig1-day7.jpeg', 'COVID-19', 'cohen'],
#        dtype='<U91'),
#  array(['13', 'nejmoa2001191_f1-PA.jpeg', 'COVID-19', 'cohen'],
#        dtype='<U91'),
#  array(['13', 'nejmoa2001191_f3-PA.jpeg', 'COVID-19', 'cohen'],
#        dtype='<U91'),
#  array(['13', 'nejmoa2001191_f4.jpeg', 'COVID-19', 'cohen'], dtype='<U91'),
#  array(['13', 'nejmoa2001191_f5-PA.jpeg', 'COVID-19', 'cohen'],
#        dtype='<U91'),
#  array(['14', 'ryct.2020200034.fig2.jpeg', 'COVID-19', 'cohen'],
#        dtype='<U91'),
#  array(['15', 'ryct.2020200034.fig5-day0.jpeg', 'COVID-19', 'cohen'],
#        dtype='<U91'),
#  array(['15', 'ryct.2020200034.fig5-day4.jpeg', 'COVID-19', 'cohen'],
#        dtype='<U91'),
#  array(['15', 'ryct.2020200034.fig5-day7.jpeg', 'COVID-19', 'cohen'],
#        dtype='<U91'),
#  array(['16', 'ryct.2020200028.fig1a.jpeg', 'COVID-19', 'cohen'],
#        dtype='<U91'),
#  array(['17', 'jkms-35-e79-g001-l-a.jpg', 'COVID-19', 'cohen'],
#        dtype='<U91'),
#  array(['17', 'jkms-35-e79-g001-l-b.jpg', 'COVID-19', 'cohen'],
#        dtype='<U91'),
#  array(['17', 'jkms-35-e79-g001-l-c.jpg', 'COVID-19', 'cohen'],
#        dtype='<U91'),
#  array(['18', 'radiol.2020200490.fig3.jpeg', 'COVID-19', 'cohen'],
#        dtype='<U91'),
#  array(['21', 'covid-19-pneumonia-2.jpg', 'COVID-19', 'cohen'],
#        dtype='<U91'),
#  array(['22', 'covid-19-pneumonia-7-PA.jpg', 'COVID-19', 'cohen'],
#        dtype='<U91'),
#  array(['23', 'covid-19-pneumonia-14-PA.png', 'COVID-19', 'cohen'],
#        dtype='<U91'),
#  array(['24', 'covid-19-pneumonia-12.jpg', 'COVID-19', 'cohen'],
#        dtype='<U91'),
#  array(['32', '39EE8E69-5801-48DE-B6E3-BE7D1BCF3092.jpeg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['33', '7C69C012-7479-493F-8722-ABC29C60A2DD.jpeg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['34', '2C10A413-AABE-4807-8CCE-6A2025594067.jpeg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['35', 'E1724330-1866-4581-8CD8-CEC9B8AFEDDE.jpeg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['37', 'F2DE909F-E19C-4900-92F5-8F435B031AC6.jpeg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['37', '31BA3780-2323-493F-8AED-62081B9C383B.jpeg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['39', '1312A392-67A3-4EBF-9319-810CF6DA5EF6.jpeg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['40', '23E99E2E-447C-46E5-8EB2-D35D12473C39.png', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['41', '7AF6C1AF-D249-4BD2-8C26-449304105D03.jpeg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['43', 'CD50BA96-6982-4C80-AE7B-5F67ACDBFA56.jpeg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['44', '85E52EB3-56E9-4D67-82DA-DEA247C82886.jpeg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['45', '6CB4EFC6-68FA-4CD5-940C-BEFA8DAFE9A7.jpeg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['46', '01E392EE-69F9-4E33-BFCE-E5C968654078.jpeg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['47', 'F63AB6CE-1968-4154-A70F-913AF154F53D.jpeg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['48', '2C26F453-AF3B-4517-BB9E-802CF2179543.jpeg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['49', '93FE0BB1-022D-4F24-9727-987A07975FFB.jpeg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['50', 'B59DD164-51D5-40DF-A926-6A42DD52EBE8.jpeg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['51', 'F4341CE7-73C9-45C6-99C8-8567A5484B63.jpeg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['51', 'E63574A7-4188-4C8D-8D17-9D67A18A1AFA.jpeg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['52', '5CBC2E94-D358-401E-8928-965CCD965C5C.jpeg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['53', '446B2CB6-B572-40AB-B01F-1910CA07086A.jpeg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['54', '80446565-E090-4187-A031-9D3CEAA586C8.jpeg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['55', '7E335538-2F86-424E-A0AB-6397783A38D0.jpeg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['56', 'D7AF463C-2369-492D-908D-BE1911CCD74C.jpeg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['57', 'all14238-fig-0001-m-b.jpg', 'COVID-19', 'cohen'],
#        dtype='<U91'),
#  array(['57', 'all14238-fig-0001-m-c.jpg', 'COVID-19', 'cohen'],
#        dtype='<U91'),
#  array(['58', 'all14238-fig-0002-m-d.jpg', 'COVID-19', 'cohen'],
#        dtype='<U91'),
#  array(['58', 'all14238-fig-0002-m-e.jpg', 'COVID-19', 'cohen'],
#        dtype='<U91'),
#  array(['58', 'all14238-fig-0002-m-f.jpg', 'COVID-19', 'cohen'],
#        dtype='<U91'),
#  array(['59', '1-s2.0-S1684118220300608-main.pdf-001.jpg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['59', '1-s2.0-S1684118220300608-main.pdf-002.jpg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['60', 'ciaa199.pdf-001-a.png', 'COVID-19', 'cohen'], dtype='<U91'),
#  array(['61', 'ciaa199.pdf-001-b.png', 'COVID-19', 'cohen'], dtype='<U91'),
#  array(['63', 'kjr-21-e24-g001-l-a.jpg', 'COVID-19', 'cohen'], dtype='<U91'),
#  array(['64', 'kjr-21-e24-g002-l-a.jpg', 'COVID-19', 'cohen'], dtype='<U91'),
#  array(['65', 'kjr-21-e24-g003-l-a.jpg', 'COVID-19', 'cohen'], dtype='<U91'),
#  array(['67', '1-s2.0-S1684118220300682-main.pdf-002-a1.png', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['67', '1-s2.0-S1684118220300682-main.pdf-002-a2.png', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['68', '1-s2.0-S1684118220300682-main.pdf-003-b1.png', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['68', '1-s2.0-S1684118220300682-main.pdf-003-b2.png', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['69', 'gr1_lrg-a.jpg', 'COVID-19', 'cohen'], dtype='<U91'),
#  array(['69', 'gr1_lrg-b.jpg', 'COVID-19', 'cohen'], dtype='<U91'),
#  array(['70', '7D2CF6CE-F529-4470-8356-D33FFAF98600.jpeg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['70', 'FE9F9A5D-2830-46F9-851B-1FF4534959BE.jpeg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['71', '171CB377-62FF-4B76-906C-F3787A01CB2E.jpeg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['71', '5931B64A-7B97-485D-BE60-3F1EA76BC4F0.jpeg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['71', 'C6EA0BE5-B01E-4113-B194-18D956675E25.jpeg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['72', '7EF28E12-F628-4BEC-A8C5-E6277C2E4F60.png', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['73', '41591_2020_819_Fig1_HTML.webp-day5.png', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['73', '41591_2020_819_Fig1_HTML.webp-day10.png', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['74', '5e6dd879fde9502400e58b2f.jpeg', 'COVID-19', 'cohen'],
#        dtype='<U91'),
#  array(['75', 'covid-19-pneumonia-19.jpg', 'COVID-19', 'cohen'],
#        dtype='<U91'),
#  array(['76', 'kjr-21-e25-g001-l-a.jpg', 'COVID-19', 'cohen'], dtype='<U91'),
#  array(['77', '03BF7561-A9BA-4C3C-B8A0-D3E585F73F3C.jpeg', 'COVID-19',
#         'cohen'], dtype='<U91'),
# ...
#         'cohen'], dtype='<U91'),
#  array(['426a',
#         'ansu-publish-ahead-of-print-10.1097.sla.0000000000003955-g001-a.png',
#         'COVID-19', 'cohen'], dtype='<U91'),
#  array(['426a',
#         'ansu-publish-ahead-of-print-10.1097.sla.0000000000003955-g001-c.png',
#         'COVID-19', 'cohen'], dtype='<U91'),
#  array(['426b',
#         'ansu-publish-ahead-of-print-10.1097.sla.0000000000003955-g001-d.png',
#         'COVID-19', 'cohen'], dtype='<U91'),
#  array(['426b',
#         'ansu-publish-ahead-of-print-10.1097.sla.0000000000003955-g001-f.png',
#         'COVID-19', 'cohen'], dtype='<U91'),
#  array(['427a', 'aqaa062i0002-a.png', 'COVID-19', 'cohen'], dtype='<U91'),
#  array(['427b', 'aqaa062i0002-b.png', 'COVID-19', 'cohen'], dtype='<U91'),
#  array(['445', 'be835db3a56b5f76d607061dbb82a5_jumbo.jpeg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['446', '3c48faa5dc2f1540fda696bae045ba_jumbo.jpeg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['446', '447d65b38231a1031586b304bc5837_jumbo.jpeg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['446', '81af553601a1bc1fdf81c99436a50b_jumbo.jpeg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['446', 'f46a9bfc7222e61e099a25ab9267da_jumbo.jpeg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['447', '882fd7ec99b523aead995d78f3129f_jumbo.jpeg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['447', '4cb2f877226f5e02b3064e1e52075f_jumbo.jpeg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['447', '556e19b9d38e2199dfa8722ddff25f_jumbo.jpeg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['448', '8781ac6b9589f3646d2bbfff8f9015_jumbo.jpeg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['459', '078d2e0b3e4fec1d603efb0e818c31_jumbo.jpeg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['465', 'c94ef38ddb2d94aa11828716777139_jumbo.jpeg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['471', '16953_1_1.jpg', 'COVID-19', 'cohen'], dtype='<U91'),
#  array(['471', '16953_3_1.jpg', 'COVID-19', 'cohen'], dtype='<U91'),
#  array(['471', '16953_4_1.jpg', 'COVID-19', 'cohen'], dtype='<U91'),
#  array(['471', '16953_5_1.jpg', 'COVID-19', 'cohen'], dtype='<U91'),
#  array(['472', '16892_2_1.png', 'COVID-19', 'cohen'], dtype='<U91'),
#  array(['473', '16883_1_1.png', 'COVID-19', 'cohen'], dtype='<U91'),
#  array(['474', '2edb88df42cab5e5fbc18b3965e0bd_jumbo.jpeg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['475', '16858_1_1.png', 'COVID-19', 'cohen'], dtype='<U91'),
#  array(['475', '16858_3_1.png', 'COVID-19', 'cohen'], dtype='<U91'),
#  array(['476', '16865_1_1.jpg', 'COVID-19', 'cohen'], dtype='<U91'),
#  array(['COVID-00001', 'COVID-00001.jpg', 'COVID-19', 'fig1'], dtype='<U91'),
#  array(['COVID-00004', 'COVID-00004.jpg', 'COVID-19', 'fig1'], dtype='<U91'),
#  array(['COVID-00006', 'COVID-00006.jpg', 'COVID-19', 'fig1'], dtype='<U91'),
#  array(['COVID-00008', 'COVID-00008.jpg', 'COVID-19', 'fig1'], dtype='<U91'),
#  array(['COVID-00009', 'COVID-00009.jpg', 'COVID-19', 'fig1'], dtype='<U91'),
#  array(['COVID-00011', 'COVID-00011.jpg', 'COVID-19', 'fig1'], dtype='<U91'),
#  array(['COVID-00012', 'COVID-00012.jpg', 'COVID-19', 'fig1'], dtype='<U91'),
#  array(['COVID-00015a', 'COVID-00015a.png', 'COVID-19', 'fig1'],
#        dtype='<U91'),
#  array(['COVID-00015b', 'COVID-00015b.png', 'COVID-19', 'fig1'],
#        dtype='<U91'),
#  array(['COVID-00016', 'COVID-00016.jpg', 'COVID-19', 'fig1'], dtype='<U91'),
#  array(['COVID-00017', 'COVID-00017.jpg', 'COVID-19', 'fig1'], dtype='<U91'),
#  array(['COVID-00018', 'COVID-00018.jpg', 'COVID-19', 'fig1'], dtype='<U91'),
#  array(['COVID-00020', 'COVID-00020.jpg', 'COVID-19', 'fig1'], dtype='<U91'),
#  array(['COVID-00021', 'COVID-00021.jpg', 'COVID-19', 'fig1'], dtype='<U91'),
#  array(['COVID-00022', 'COVID-00022.jpg', 'COVID-19', 'fig1'], dtype='<U91'),
#  array(['COVID-00024', 'COVID-00024.jpg', 'COVID-19', 'fig1'], dtype='<U91'),
#  array(['COVID-00039a', 'COVID-00039a.jpg', 'COVID-19', 'fig1'],
#        dtype='<U91'),
#  array(['COVID-00039b', 'COVID-00039b.jpg', 'COVID-19', 'fig1'],
#        dtype='<U91'),
#  array(['COVID-00039c', 'COVID-00039c.jpg', 'COVID-19', 'fig1'],
#        dtype='<U91'),
#  array(['COVID-00043a', 'COVID-00043a.jpg', 'COVID-19', 'fig1'],
#        dtype='<U91'),
#  array(['COVID-00043b', 'COVID-00043b.jpg', 'COVID-19', 'fig1'],
#        dtype='<U91'),
#  array(['COVID-00045', 'COVID-00045.png', 'COVID-19', 'fig1'], dtype='<U91'),
#  array(['COVID-00046', 'COVID-00046.png', 'COVID-19', 'fig1'], dtype='<U91'),
#  array(['COVID-00048', 'COVID-00048.png', 'COVID-19', 'fig1'], dtype='<U91'),
#  array(['ANON196',
#         'CR.1.2.840.113564.1722810170.20200318082923328940.1003000225002.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON170',
#         'CR.1.2.840.113564.1722810170.20200320011259312440.1003000225002.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON66',
#         'CR.1.2.840.113564.1722810170.20200320170359875720.1003000225002.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON38',
#         'CR.1.2.840.113564.1722810170.20200322160314468140.1003000225002.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON25',
#         'CR.1.2.840.113564.1722810170.20200324165957625920.1003000225002.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON58',
#         'CR.1.2.840.113564.1722810170.20200326010813390400.1003000225002.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON119',
#         'CR.1.2.840.113564.1722810170.20200327151518468570.1003000225002.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON119',
#         'CR.1.2.840.113564.1722810170.20200327154027828590.1003000225002.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON200',
#         'CR.1.2.840.113564.1722810170.20200405065153640420.1003000225002.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON232',
#         'CR.1.2.840.113564.1722810170.20200408094743609850.1003000225002.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON157',
#         'CR.1.2.840.113564.1722810170.20200416105826265860.1003000225002.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON78',
#         'CR.1.2.840.113564.1722810170.20200416110930703890.1003000225002.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON169',
#         'CR.1.2.840.113564.192168196.2020040116564476574.1203801020003.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON209',
#         'DX.1.2.840.113564.1722810162.20200322102521497410.1203801020003.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON199',
#         'DX.1.2.840.113564.1722810162.202003241226081857.1203801020003.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON14',
#         'DX.1.2.840.113564.1722810162.20200325102716421950.1203801020003.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON80',
#         'DX.1.2.840.113564.1722810162.20200325125743092120.1203801020003.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON60',
#         'DX.1.2.840.113564.1722810162.20200326123403551130.1203801020003.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON60',
#         'DX.1.2.840.113564.1722810162.20200326123552855170.1203801020003.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON159',
#         'DX.1.2.840.113564.1722810162.20200327160432430120.1203801020003.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON202',
#         'DX.1.2.840.113564.1722810162.20200331100140006240.1203801020003.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON96',
#         'DX.1.2.840.113564.1722810162.20200401122015054240.1203801020003.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON136',
#         'DX.1.2.840.113564.1722810162.20200405112431725920.1203801020003.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON188',
#         'DX.1.2.840.113564.1722810162.20200405142816863980.1203801020003.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON68',
#         'DX.1.2.840.113564.1722810162.20200420135116095500.1203801020003.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['COVID 1', 'COVID(1).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 2', 'COVID(2).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 3', 'COVID(3).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 4', 'COVID(4).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 5', 'COVID(5).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 6', 'COVID(6).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 7', 'COVID(7).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 8', 'COVID(8).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 9', 'COVID(9).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 10', 'COVID(10).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 11', 'COVID(11).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 12', 'COVID(12).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 13', 'COVID(13).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 14', 'COVID(14).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 15', 'COVID(15).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 16', 'COVID(16).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 17', 'COVID(17).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 18', 'COVID(18).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 19', 'COVID(19).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 20', 'COVID(20).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 21', 'COVID(21).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 22', 'COVID(22).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 23', 'COVID(23).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 24', 'COVID(24).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 25', 'COVID(25).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 26', 'COVID(26).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 27', 'COVID(27).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 28', 'COVID(28).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 29', 'COVID(29).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 30', 'COVID(30).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 31', 'COVID(31).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 32', 'COVID(32).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 33', 'COVID(33).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 34', 'COVID(34).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 35', 'COVID(35).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 36', 'COVID(36).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 37', 'COVID(37).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 38', 'COVID(38).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 39', 'COVID(39).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 40', 'COVID(40).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 41', 'COVID(41).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 42', 'COVID(42).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 43', 'COVID(43).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 44', 'COVID(44).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 45', 'COVID(45).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 46', 'COVID(46).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 47', 'COVID(47).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 48', 'COVID(48).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 49', 'COVID(49).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 50', 'COVID(50).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 51', 'COVID(51).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 52', 'COVID(52).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 53', 'COVID(53).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 54', 'COVID(54).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 55', 'COVID(55).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 56', 'COVID(56).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 57', 'COVID(57).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 58', 'COVID(58).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 59', 'COVID(59).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 60', 'COVID(60).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 61', 'COVID(61).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 62', 'COVID(62).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 63', 'COVID(63).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 64', 'COVID(64).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 65', 'COVID(65).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 66', 'COVID(66).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 67', 'COVID(67).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 68', 'COVID(68).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 69', 'COVID(69).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 71', 'COVID(71).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 73', 'COVID(73).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 74', 'COVID(74).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 75', 'COVID(75).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 76', 'COVID(76).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 78', 'COVID(78).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 79', 'COVID(79).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 80', 'COVID(80).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 82', 'COVID(82).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 83', 'COVID(83).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 84', 'COVID(84).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 85', 'COVID(85).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 86', 'COVID(86).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 88', 'COVID(88).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 89', 'COVID(89).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 90', 'COVID(90).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 91', 'COVID(91).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 92', 'COVID(92).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 93', 'COVID(93).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 96', 'COVID(96).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 97', 'COVID(97).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 98', 'COVID(98).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 99', 'COVID(99).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 100', 'COVID(100).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 101', 'COVID(101).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 102', 'COVID(102).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 103', 'COVID(103).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 104', 'COVID(104).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 105', 'COVID(105).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 108', 'COVID(108).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 109', 'COVID(109).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 110', 'COVID(110).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 111', 'COVID(111).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 112', 'COVID(112).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 113', 'COVID(113).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 114', 'COVID(114).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 115', 'COVID(115).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 117', 'COVID(117).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  ...]

# %%
final_train_data = [[]]

for sample in train:
    if len(sample) == 4:
        if sample[2] == "COVID-19":
            final_train_data.append([sample[1], 'positive'])
        else:
            final_train_data.append([sample[1], 'negative'])
    else:
        if sample[2] == "COVID-19":
            final_train_data.append(sample[1], 'positive')
        else:
            final_train_data.append([sample[1], 'negative'])

del final_train_data[0]

# %%
final_train_data
# Out:
# [['ARDSSevere.png', 'negative'],
#  ['acute-respiratory-distress-syndrome-ards-1.jpg', 'negative'],
#  ['acute-respiratory-distress-syndrome-ards.jpg', 'negative'],
#  ['ards-secondary-to-tiger-snake-bite.png', 'negative'],
#  ['pneumocystis-pneumonia-2-PA.png', 'negative'],
#  ['F051E018-DAD1-4506-AD43-BE4CA29E960B.jpeg', 'negative'],
#  ['pneumocystis-jirovecii-pneumonia-3-1.jpg', 'negative'],
#  ['pneumocystis-jirovecii-pneumonia-3-2.jpg', 'negative'],
#  ['pneumocystis-jirovecii-pneumonia-3-3.jpg', 'negative'],
#  ['pneumocystis-pneumonia-1.jpg', 'negative'],
#  ['X-ray_of_cyst_in_pneumocystis_pneumonia_1.jpg', 'negative'],
#  ['pneumocystis-pneumonia-8.jpg', 'negative'],
#  ['pneumocystis-carinii-pneumonia-1-PA.jpg', 'negative'],
#  ['pneumocystis-pneumonia-12.png', 'negative'],
#  ['pneumocystis-jiroveci-pneumonia-2.png', 'negative'],
#  ['pneumocystis-jirovecii-pneumonia-2.jpg', 'negative'],
#  ['pneumocystis-jiroveci-pneumonia-4-PA.png', 'negative'],
#  ['covid-19-pneumonia-58-prior.jpg', 'negative'],
#  ['16745_2_1.PNG', 'negative'],
#  ['16745_3_1.png', 'negative'],
#  ['16745_6_1.png', 'negative'],
#  ['a4318ac9.jpg', 'negative'],
#  ['2c35005f.jpg', 'negative'],
#  ['ada8c494.jpg', 'negative'],
#  ['16583_1_1.jpg', 'negative'],
#  ['16583_3_1.jpg', 'negative'],
#  ['000001-2.jpg', 'negative'],
#  ['000005-5-a.jpg', 'negative'],
#  ['000005-3.png', 'negative'],
#  ['000006-2.png', 'negative'],
#  ['000007-2.png', 'negative'],
#  ['000010-2.png', 'negative'],
#  ['000001-9-a.jpg', 'negative'],
#  ['000002-11-a.jpg', 'negative'],
#  ['000001-3.png', 'negative'],
#  ['000002-4.png', 'negative'],
#  ['000003-4.png', 'negative'],
#  ['000004-3.png', 'negative'],
#  ['000001-12.jpg', 'negative'],
#  ['000001.jpg', 'negative'],
#  ['000008-8.jpg', 'negative'],
#  ['000016.jpg', 'negative'],
#  ['000024-1.jpg', 'negative'],
#  ['000001-17.jpg', 'negative'],
#  ['000002-19-a.jpg', 'negative'],
#  ['000001-6.png', 'negative'],
#  ['10.1016-slash-j.hrcr.2020.04.015-fig3-a.png', 'negative'],
#  ['1-s2.0-S2214250920300834-gr1_lrg-d.png', 'negative'],
#  ['1-s2.0-S2213716520301168-gr1_lrg-c.png', 'negative'],
#  ['1-s2.0-S1341321X20301124-gr3_lrg-a.png', 'negative'],
#  ['1-s2.0-S1341321X20301124-gr3_lrg-b.png', 'negative'],
#  ['1-s2.0-S1059131120301151-gr2-e.png', 'negative'],
#  ['000001-24.jpg', 'negative'],
#  ['000006-17.jpg', 'negative'],
#  ['000007-15.jpg', 'negative'],
#  ['665f7ed5dcf52f235d8abed8cc200c_jumbo.jpeg', 'negative'],
#  ['5f8aaa4e85af075412849ebf8ebb54_jumbo-1.jpg', 'negative'],
#  ['13cd850b02d1afe48c113a73eed882_jumbo-1.jpg', 'negative'],
#  ['b50c02b92f2b98f5e1477ff759ce94_jumbo-1.jpg', 'negative'],
#  ['94c6945194a265ae1301bec234a7e0_jumbo-1.jpg', 'negative'],
#  ['52a8b6bf730b648d37b37d2aa51fd3_jumbo-1.jpg', 'negative'],
#  ['4e1dc09c3abe03a3efb72d494ddb6f_jumbo-2.jpeg', 'negative'],
#  ['9a4e0141fd7681c4026b55b4e13914_jumbo-2.jpeg', 'negative'],
#  ['e9cc806fc1c90195d999dc8d022d28_jumbo-2.jpeg', 'negative'],
#  ['bb25b35e1cc5cb0984ead37363db0e_jumbo-2.jpeg', 'negative'],
#  ['582f068ae16494e015cf2b2ed90388_jumbo-1.jpeg', 'negative'],
#  ['3d4364c0e44859e86017ee1660112e_jumbo-1.jpeg', 'negative'],
#  ['487354e56da5b0363458d0297446f0_jumbo-1.jpeg', 'negative'],
#  ['946b48f8564d681eb8950ea8a659e0_jumbo-1.jpeg', 'negative'],
#  ['f410057190635755d60158d1595d67_jumbo-1.jpeg', 'negative'],
#  ['56bc74129531580d3c40b1f8ae77ab_jumbo.jpeg', 'negative'],
#  ['d84789f9ece74ea65e7ec2c4faaaf3_jumbo.jpeg', 'negative'],
#  ['981f82325fcc645a78a1732ab783f1_jumbo.jpeg', 'negative'],
#  ['26eecee1e498237cc3ea3274b79ff0_jumbo.jpg', 'negative'],
#  ['21f0cfca1c3d5d11e9eb8f6c670f73_jumbo.jpg', 'negative'],
#  ['b85b6449f7c3bfc841a973cca0ada7_jumbo.jpg', 'negative'],
#  ['f72b17e863d0f958b65379b3669238_jumbo.jpg', 'negative'],
#  ['19876b357ac5c998a06d9614b6148a_jumbo.jpeg', 'negative'],
#  ['22ebbc464e16ea1217228e3c9f4935_jumbo.jpeg', 'negative'],
#  ['cdf5605e45874c28262c81b7ab80b3_jumbo.jpeg', 'negative'],
#  ['82cb30b7678c6da229c6dc222c39c9_jumbo.jpeg', 'negative'],
#  ['84da526d0453b9b9e7896631e6b366_jumbo.jpeg', 'negative'],
#  ['503d2fbe68cd143b0f15749b4f816b_jumbo.jpeg', 'negative'],
#  ['a24181c437aca166f7aeccc62ba28a_jumbo.jpg', 'negative'],
#  ['1e64990d1b40c1758a2aaa9c7f7a85_jumbo.jpeg', 'negative'],
#  ['7223b8ad031187d9a142d7f7ca02c9_jumbo.jpeg', 'negative'],
#  ['3392dc7d262e28423caca517f98c2e_jumbo.jpeg', 'negative'],
#  ['ec3a480c0926ded74429df416cfb05_jumbo.jpeg', 'negative'],
#  ['076d9f1ab85d17bcf0f4f207891974_jumbo.jpg', 'negative'],
#  ['a72aeb349a63c79ed24e473c434efe_jumbo.jpg', 'negative'],
#  ['ba45a47c3ef5060ec39891046be7ca_jumbo.jpg', 'negative'],
#  ['6f36c4ad54047bc52b38fd8c9d1e22_jumbo.jpg', 'negative'],
#  ['621f53af15cf08e6e13cb6812eead9_jumbo.jpg', 'negative'],
#  ['6646071b.jpg', 'negative'],
#  ['5359825d.jpg', 'negative'],
#  ['0cd9fcb6.jpg', 'negative'],
#  ['ce09cfab.jpg', 'negative'],
#  ['b0500187.jpg', 'negative'],
#  ['40f355ec.jpg', 'negative'],
#  ['e6eaadf0.jpg', 'negative'],
#  ['34d999a9.jpg', 'negative'],
#  ['fbb18dc0.jpg', 'negative'],
#  ['54d57e77.jpg', 'negative'],
#  ['a7e0a141.jpg', 'negative'],
#  ['d806f9a1.jpg', 'negative'],
#  ['19a01707.jpg', 'negative'],
#  ['bf551b8b.jpg', 'negative'],
#  ['1e534853.jpg', 'negative'],
#  ['aa9655de.jpg', 'negative'],
#  ['073a8f93.jpg', 'negative'],
#  ['7a9ec606.jpg', 'negative'],
#  ['88859dc1.jpg', 'negative'],
#  ['3a81faf3.jpg', 'negative'],
#  ['bcb814aa.jpg', 'negative'],
#  ['76093afc.jpg', 'negative'],
#  ['000012.jpg', 'negative'],
#  ['16755_1_1.jpg', 'negative'],
#  ['000001-1.jpg', 'negative'],
#  ['000001-3.jpg', 'negative'],
#  ['000003-1.jpg', 'negative'],
#  ['000003-2.jpg', 'negative'],
#  ['000001-4.jpg', 'negative'],
#  ['000002-3.jpg', 'negative'],
#  ['000003-3.jpg', 'negative'],
#  ['000001-6.jpg', 'negative'],
#  ['000002-4.jpg', 'negative'],
#  ['000001-7.jpg', 'negative'],
#  ['000003-4.jpg', 'negative'],
#  ['000001-8.jpg', 'negative'],
#  ['000002-5.jpg', 'negative'],
#  ['000001-9.jpg', 'negative'],
#  ['000001-10.jpg', 'negative'],
#  ['000001-11.jpg', 'negative'],
#  ['000001-13.jpg', 'negative'],
#  ['000001.png', 'negative'],
#  ['000007.png', 'negative'],
#  ['16497_1_1.png', 'negative'],
#  ['000001-14.jpg', 'negative'],
#  ['000002-6.jpg', 'negative'],
#  ['000001-15.jpg', 'negative'],
#  ['000002-7.jpg', 'negative'],
#  ['000003-5.jpg', 'negative'],
#  ['untitled.001_0.jpeg', 'negative'],
#  ['000001-1.png', 'negative'],
#  ['000003-6.jpg', 'negative'],
#  ['000001-4.png', 'negative'],
#  ['000001-18.jpg', 'negative'],
#  ['000010.jpg', 'negative'],
#  ['000001-20.jpg', 'negative'],
#  ['000005-1.jpg', 'negative'],
#  ['000007.jpg', 'negative'],
#  ['000012-1.jpg', 'negative'],
#  ['000001-5.png', 'negative'],
#  ['MERS-CoV-1-s2.0-S0378603X1500248X-gr4e.jpg', 'negative'],
#  ['1-s2.0-S0378603X1500248X-gr2a.jpg', 'negative'],
#  ['1-s2.0-S0378603X1500248X-gr2b.jpg', 'negative'],
#  ['1-s2.0-S0378603X1500248X-gr2c.jpg', 'negative'],
#  ['1-s2.0-S0378603X1500248X-gr2d.jpg', 'negative'],
#  ['1-s2.0-S0378603X1500248X-gr3a.jpg', 'negative'],
#  ['1-s2.0-S0378603X1500248X-gr3b.jpg', 'negative'],
#  ['1-s2.0-S0378603X1500248X-gr3d.jpg', 'negative'],
#  ['1-s2.0-S0378603X1500248X-gr4a.jpg', 'negative'],
#  ['1-s2.0-S0378603X1500248X-gr4c.jpg', 'negative'],
#  ['1-s2.0-S0378603X1500248X-gr4e.jpg', 'negative'],
#  ['fff13f3a.jpg', 'negative'],
#  ['c4a0e11a.jpg', 'negative'],
#  ['33ad0dcb.jpg', 'negative'],
#  ['26e8db49.jpg', 'negative'],
#  ['d2af569b.jpg', 'negative'],
#  ['2ecd360d.jpg', 'negative'],
#  ['26b79d0d.jpg', 'negative'],
#  ['2086b9e1.jpg', 'negative'],
#  ['3309d07c.jpg', 'negative'],
#  ['341e2287.jpg', 'negative'],
#  ['0ac7580d.jpg', 'negative'],
#  ['86ee6e6c.jpg', 'negative'],
#  ['b03ef875.jpg', 'negative'],
#  ['f875007a.jpg', 'negative'],
#  ['cb60786c.jpg', 'negative'],
#  ['1d40779e.jpg', 'negative'],
#  ['0cea09eb.jpg', 'negative'],
#  ['27a70642.jpg', 'negative'],
#  ['e53ea41a.jpg', 'negative'],
#  ['ce68550a.jpg', 'negative'],
#  ['2fdd55b8.jpg', 'negative'],
#  ['f722466f.jpg', 'negative'],
#  ['3964b961.jpg', 'negative'],
#  ['7b68340a.jpg', 'negative'],
#  ['90c1e3ef.jpg', 'negative'],
#  ['0957ce54.jpg', 'negative'],
#  ['cfcdf8d9.jpg', 'negative'],
#  ['24de8686.jpg', 'negative'],
#  ['a228e110.jpg', 'negative'],
#  ['d2c83bde.jpg', 'negative'],
#  ['78af4c1d.jpg', 'negative'],
#  ['85540916.jpg', 'negative'],
#  ['a8685b98.jpg', 'negative'],
#  ['09258248.jpg', 'negative'],
#  ['1e33b16c.jpg', 'negative'],
#  ['430f21e7.jpg', 'negative'],
#  ['587e7c1a.jpg', 'negative'],
#  ['98c24e39.jpg', 'negative'],
#  ['7940dea2.jpg', 'negative'],
#  ['f0a93ef2.jpg', 'negative'],
#  ['183af0d0.jpg', 'negative'],
#  ['4b907d01.jpg', 'negative'],
#  ['40f67745.jpg', 'negative'],
#  ['242a639e.jpg', 'negative'],
#  ['e104f46d.jpg', 'negative'],
#  ['15d945b8.jpg', 'negative'],
#  ['ba040c5e.jpg', 'negative'],
#  ['b37c225f.jpg', 'negative'],
#  ['23823ebc.jpg', 'negative'],
#  ['e87352fc.jpg', 'negative'],
#  ['27f5a41d.jpg', 'negative'],
#  ['006f3a8a.jpg', 'negative'],
#  ['1d6c4b7c.jpg', 'negative'],
#  ['18017511.jpg', 'negative'],
#  ['689836b5.jpg', 'negative'],
#  ['1ae7877e.jpg', 'negative'],
#  ['5f001e0b.jpg', 'negative'],
#  ['e9877113.jpg', 'negative'],
#  ['c873402e.jpg', 'negative'],
#  ['5b324cc7.jpg', 'negative'],
#  ['7185bd4a8cc3280902117d034c7653_jumbo.jpg', 'negative'],
#  ['75fb7cd80d5ca4074c474f93471ad4_jumbo.jpeg', 'negative'],
#  ['01ec02c48ce0120d57456b2ee2d02f_jumbo.jpeg', 'negative'],
#  ['d815245ec98b5f0efc73b89daef72c_jumbo.jpg', 'negative'],
#  ['616f829f195d0cd856616586c7c35e_jumbo.jpeg', 'negative'],
#  ['71b364138ea4986831b3778081cd2e_jumbo.jpeg', 'negative'],
#  ['ffad3e6c27fe36031249c81647800f_jumbo.jpeg', 'negative'],
#  ['b2f42e0cdfcbe32f189eb467b05e24_jumbo.jpg', 'negative'],
#  ['8f46c8ad3d40a93b4a313f15092e1d_jumbo.jpeg', 'negative'],
#  ['bc370d0566b31259c2d9544748eb21_jumbo.jpeg', 'negative'],
#  ['8b7aeaa2063bf9a12ed6b79c173f4e_jumbo.jpeg', 'negative'],
#  ['1538fbfe9d0872739b00f5a51e4fdc_jumbo.jpeg', 'negative'],
#  ['7a7044c64a87936f09fee9a7f5c5fa_jumbo.jpeg', 'negative'],
#  ['4e74cbafeab0bfd317a93e1aace6cf_jumbo.jpg', 'negative'],
#  ['2264f643b18b1010ec10a850f17550_jumbo.jpeg', 'negative'],
#  ['55f5189d2c23688ac8dc1d58eb65cf_jumbo.jpg', 'negative'],
#  ['02b973e10caa192fd4e6825ad4aeaf_jumbo-10.jpeg', 'negative'],
#  ['d2c8a74b37d8d1581ea2a8fe865ef3_jumbo-10.jpeg', 'negative'],
#  ['072ecaf8c60a81980abb57150a8016_jumbo-9.jpeg', 'negative'],
#  ['ff33c406392b968d483174c97eb857_jumbo-9.jpeg', 'negative'],
#  ['000001-266.jpg', 'negative'],
#  ['000001-272.jpg', 'negative'],
#  ['CR.1.2.840.113564.1722810170.20200317090830828260.1003000225002.png',
#   'negative'],
#  ['CR.1.2.840.113564.1722810170.20200317104341875470.1003000225002.png',
#   'negative'],
#  ['CR.1.2.840.113564.1722810170.20200319202613984410.1003000225002.png',
#   'negative'],
#  ['CR.1.2.840.113564.1722810170.20200323115834968210.1003000225002.png',
#   'negative'],
#  ['CR.1.2.840.113564.1722810170.202003241816485934.1003000225002.png',
#   'negative'],
#  ['CR.1.2.840.113564.1722810170.20200401171818781600.1003000225002.png',
#   'negative'],
#  ['CR.1.2.840.113564.1722810170.20200403010103781780.1003000225002.png',
#   'negative'],
#  ['CR.1.2.840.113564.192168196.2020031913094890017.1203801020003.png',
#   'negative'],
#  ['CR.1.2.840.113564.192168196.2020031913311637123.1203801020003.png',
#   'negative'],
#  ['CR.1.2.840.113564.192168196.2020031914133530635.1203801020003.png',
#   'negative'],
#  ['CR.1.2.840.113564.192168196.2020031914434008949.1203801020003.png',
#   'negative'],
#  ['CR.1.2.840.113564.192168196.2020032008575844669.1203801020003.png',
#   'negative'],
#  ['CR.1.2.840.113564.192168196.2020032009002413573.1203801020003.png',
#   'negative'],
#  ['CR.1.2.840.113564.192168196.2020032009520943077.1203801020003.png',
#   'negative'],
#  ['CR.1.2.840.113564.192168196.2020032413222814777.1203801020003.png',
#   'negative'],
#  ['CR.1.2.840.113564.192168196.2020032712415994976.1203801020003.png',
#   'negative'],
#  ['CR.1.2.840.113564.192168196.2020033016123149069.1203801020003.png',
#   'negative'],
#  ['CR.1.2.840.113564.192168196.2020033115253391026.1203801020003.png',
#   'negative'],
#  ['CR.1.2.840.113564.192168196.2020040117583329780.1203801020003.png',
#   'negative'],
#  ['CR.1.2.840.113564.192168196.2020040314541260251.1203801020003.png',
#   'negative'],
#  ['CR.1.2.840.113564.192168196.2020040708262888222.1203801020003.png',
#   'negative'],
#  ['CR.1.2.840.113564.192168196.2020041316410681120.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200320112920531100.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200320114116138220.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200320150341771440.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200320155115417540.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200320175830093580.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200321085646975740.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200321114314263800.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200321204028829980.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.202003212127446125.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200322012248568150.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200322143316916570.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200323104202808100.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200323113158393220.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200324140423562310.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200324163640450390.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200324173713500510.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.202003251249284366.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200325130434611240.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200325133712872360.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200325160609990420.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200325180041010540.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200325180923403640.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200326103306090980.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200327115150971770.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200327130648390830.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200327135950280950.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200328130557219720.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200330101715842390.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200330115928823450.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200330142125620570.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200330155549529100.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200331093347514180.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200331165352707460.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200331235358718640.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200401095800552100.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200403103712240360.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200403105318208480.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200403113227763540.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200404145807490420.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200404194854145480.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200404203720370540.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200404210401196600.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200405000323941660.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200405214257011250.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200406082745416370.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200406152138599630.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200407095712184770.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200407110159061830.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200407154351156930.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200408152416905270.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200408170334886370.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200409100734996750.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200409131002213950.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200410122807096300.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200410172247966360.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200410175512031420.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200413144300534160.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200413163143169320.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200414101717389720.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200414150507492960.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.202004141559081673.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200414192734848390.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200414235332189450.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200415172911278870.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200416083007099140.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200416130101712300.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200416135234642360.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200416190453105480.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200416191632203540.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200417024634079600.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200417102240621720.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200417105359936840.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200417110000959900.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.202004171314057425.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200417134736990110.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200417201319616230.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200417214150749290.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200418123953240490.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200418170644187730.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200419111851705930.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200420123349689300.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200420140206725640.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200420150441592700.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200420155936364760.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200420164750991860.1203801020003.png',
#   'negative'],
#  ['SARS-10.1148rg.242035193-g04mr34g0-Fig8a-day0.jpeg', 'negative'],
#  ['SARS-10.1148rg.242035193-g04mr34g0-Fig8b-day5.jpeg', 'negative'],
#  ['SARS-10.1148rg.242035193-g04mr34g0-Fig8c-day10.jpeg', 'negative'],
#  ['SARS-10.1148rg.242035193-g04mr34g04a-Fig4a-day7.jpeg', 'negative'],
#  ['SARS-10.1148rg.242035193-g04mr34g04b-Fig4b-day12.jpeg', 'negative'],
#  ['SARS-10.1148rg.242035193-g04mr34g07a-Fig7a-day5.jpeg', 'negative'],
#  ['SARS-10.1148rg.242035193-g04mr34g07b-Fig7b-day12.jpeg', 'negative'],
#  ['SARS-10.1148rg.242035193-g04mr34g09a-Fig9a-day17.jpeg', 'negative'],
#  ['SARS-10.1148rg.242035193-g04mr34g09b-Fig9b-day19.jpeg', 'negative'],
#  ['SARS-10.1148rg.242035193-g04mr34g09c-Fig9c-day27.jpeg', 'negative'],
#  ['streptococcus-pneumoniae-pneumonia-1.jpg', 'negative'],
#  ['pneumonia-7.jpg', 'negative'],
#  ['pneumococcal-pneumonia-day0.jpg', 'negative'],
#  ['pneumococcal-pneumonia-day7.jpg', 'negative'],
#  ['pneumococcal-pneumonia-day35.jpg', 'negative'],
#  ['parapneumonic-effusion-1-PA.png', 'negative'],
#  ['right-upper-lobe-pneumonia-9-PA.jpg', 'negative'],
#  ['chlamydia-pneumonia-PA.png', 'negative'],
#  ['aspiration-pneumonia-5-day0.jpg', 'negative'],
#  ['aspiration-pneumonia-5-day3.jpg', 'negative'],
#  ['aspiration-pneumonia-5-day10.jpg', 'negative'],
#  ['aspiration-pneumonia-5-day27.jpg', 'negative'],
#  ['cavitating-pneumonia-4-day0-PA.jpg', 'negative'],
#  ['cavitating-pneumonia-4-day28-PA.png', 'negative'],
#  ['klebsiella-pneumonia-1.jpg', 'negative'],
#  ['legionella-pneumonia-1.png', 'negative'],
#  ['legionella-pneumonia-2.jpg', 'negative'],
#  ['wong-0000.jpg', 'negative'],
#  ['wong-0002.jpg', 'negative'],
#  ['wong-0003.jpg', 'negative'],
#  ['wong-0004.jpg', 'negative'],
#  ['wong-0005.jpg', 'negative'],
#  ['16646_1_1.jpg', 'negative'],
#  ['000001-19.jpg', 'negative'],
#  ['000006-12.jpg', 'negative'],
#  ['000010-5.jpg', 'negative'],
#  ['000011-6.jpg', 'negative'],
#  ['000012-3.jpg', 'negative'],
#  ['000001-27.jpg', 'negative'],
#  ['f6ece95b172eadba762bf3daef7441_jumbo-1.jpeg', 'negative'],
#  ['000004.jpg', 'negative'],
#  ['000005.jpg', 'negative'],
#  ['000003.jpg', 'negative'],
#  ['000004.png', 'negative'],
#  ['4c8dee3d9fe81567b98ed1b0b2b4c6_jumbo.JPG', 'negative'],
#  ['3e9d9c9b02b9bcd81c851134667e76_jumbo.jpg', 'negative'],
#  ['2fc8a7c61c76f13ee7f9306b44e792_jumbo.jpg', 'negative'],
#  ['92d755fba55c3305419b5cac83fbf5_jumbo.jpg', 'negative'],
#  ['6ffc98957c18d4e3f2da8da48105e3_jumbo.jpg', 'negative'],
#  ['dc025523f07c043550a2c9de68ae50_jumbo.jpeg', 'negative'],
#  ['bdc40f9ad2395d88c92479089f5d1b_jumbo-10.jpeg', 'negative'],
#  ['15d081345df9ca620ebe5e76023775_jumbo-10.jpeg', 'negative'],
#  ['auntminnie-a-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg',
#   'positive'],
#  ['auntminnie-b-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg',
#   'positive'],
#  ['auntminnie-c-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg',
#   'positive'],
#  ['auntminnie-d-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg',
#   'positive'],
#  ['nejmc2001573_f1a.jpeg', 'positive'],
#  ['nejmc2001573_f1b.jpeg', 'positive'],
#  ['lancet-case2a.jpg', 'positive'],
#  ['lancet-case2b.jpg', 'positive'],
#  ['1-s2.0-S0140673620303706-fx1_lrg.jpg', 'positive'],
#  ['nCoV-radiol.2020200269.fig1-day7.jpeg', 'positive'],
#  ['nejmoa2001191_f1-PA.jpeg', 'positive'],
#  ['nejmoa2001191_f3-PA.jpeg', 'positive'],
#  ['nejmoa2001191_f4.jpeg', 'positive'],
#  ['nejmoa2001191_f5-PA.jpeg', 'positive'],
#  ['ryct.2020200034.fig2.jpeg', 'positive'],
#  ['ryct.2020200034.fig5-day0.jpeg', 'positive'],
#  ['ryct.2020200034.fig5-day4.jpeg', 'positive'],
#  ['ryct.2020200034.fig5-day7.jpeg', 'positive'],
#  ['ryct.2020200028.fig1a.jpeg', 'positive'],
#  ['jkms-35-e79-g001-l-a.jpg', 'positive'],
#  ['jkms-35-e79-g001-l-b.jpg', 'positive'],
#  ['jkms-35-e79-g001-l-c.jpg', 'positive'],
#  ['radiol.2020200490.fig3.jpeg', 'positive'],
#  ['covid-19-pneumonia-2.jpg', 'positive'],
#  ['covid-19-pneumonia-7-PA.jpg', 'positive'],
#  ['covid-19-pneumonia-14-PA.png', 'positive'],
#  ['covid-19-pneumonia-12.jpg', 'positive'],
#  ['39EE8E69-5801-48DE-B6E3-BE7D1BCF3092.jpeg', 'positive'],
#  ['7C69C012-7479-493F-8722-ABC29C60A2DD.jpeg', 'positive'],
#  ['2C10A413-AABE-4807-8CCE-6A2025594067.jpeg', 'positive'],
#  ['E1724330-1866-4581-8CD8-CEC9B8AFEDDE.jpeg', 'positive'],
#  ['F2DE909F-E19C-4900-92F5-8F435B031AC6.jpeg', 'positive'],
#  ['31BA3780-2323-493F-8AED-62081B9C383B.jpeg', 'positive'],
#  ['1312A392-67A3-4EBF-9319-810CF6DA5EF6.jpeg', 'positive'],
#  ['23E99E2E-447C-46E5-8EB2-D35D12473C39.png', 'positive'],
#  ['7AF6C1AF-D249-4BD2-8C26-449304105D03.jpeg', 'positive'],
#  ['CD50BA96-6982-4C80-AE7B-5F67ACDBFA56.jpeg', 'positive'],
#  ['85E52EB3-56E9-4D67-82DA-DEA247C82886.jpeg', 'positive'],
#  ['6CB4EFC6-68FA-4CD5-940C-BEFA8DAFE9A7.jpeg', 'positive'],
#  ['01E392EE-69F9-4E33-BFCE-E5C968654078.jpeg', 'positive'],
#  ['F63AB6CE-1968-4154-A70F-913AF154F53D.jpeg', 'positive'],
#  ['2C26F453-AF3B-4517-BB9E-802CF2179543.jpeg', 'positive'],
#  ['93FE0BB1-022D-4F24-9727-987A07975FFB.jpeg', 'positive'],
#  ['B59DD164-51D5-40DF-A926-6A42DD52EBE8.jpeg', 'positive'],
#  ['F4341CE7-73C9-45C6-99C8-8567A5484B63.jpeg', 'positive'],
#  ['E63574A7-4188-4C8D-8D17-9D67A18A1AFA.jpeg', 'positive'],
#  ['5CBC2E94-D358-401E-8928-965CCD965C5C.jpeg', 'positive'],
#  ['446B2CB6-B572-40AB-B01F-1910CA07086A.jpeg', 'positive'],
#  ['80446565-E090-4187-A031-9D3CEAA586C8.jpeg', 'positive'],
#  ['7E335538-2F86-424E-A0AB-6397783A38D0.jpeg', 'positive'],
#  ['D7AF463C-2369-492D-908D-BE1911CCD74C.jpeg', 'positive'],
#  ['all14238-fig-0001-m-b.jpg', 'positive'],
#  ['all14238-fig-0001-m-c.jpg', 'positive'],
#  ['all14238-fig-0002-m-d.jpg', 'positive'],
#  ['all14238-fig-0002-m-e.jpg', 'positive'],
#  ['all14238-fig-0002-m-f.jpg', 'positive'],
#  ['1-s2.0-S1684118220300608-main.pdf-001.jpg', 'positive'],
#  ['1-s2.0-S1684118220300608-main.pdf-002.jpg', 'positive'],
#  ['ciaa199.pdf-001-a.png', 'positive'],
#  ['ciaa199.pdf-001-b.png', 'positive'],
#  ['kjr-21-e24-g001-l-a.jpg', 'positive'],
#  ['kjr-21-e24-g002-l-a.jpg', 'positive'],
#  ['kjr-21-e24-g003-l-a.jpg', 'positive'],
#  ['1-s2.0-S1684118220300682-main.pdf-002-a1.png', 'positive'],
#  ['1-s2.0-S1684118220300682-main.pdf-002-a2.png', 'positive'],
#  ['1-s2.0-S1684118220300682-main.pdf-003-b1.png', 'positive'],
#  ['1-s2.0-S1684118220300682-main.pdf-003-b2.png', 'positive'],
#  ['gr1_lrg-a.jpg', 'positive'],
#  ['gr1_lrg-b.jpg', 'positive'],
#  ['7D2CF6CE-F529-4470-8356-D33FFAF98600.jpeg', 'positive'],
#  ['FE9F9A5D-2830-46F9-851B-1FF4534959BE.jpeg', 'positive'],
#  ['171CB377-62FF-4B76-906C-F3787A01CB2E.jpeg', 'positive'],
#  ['5931B64A-7B97-485D-BE60-3F1EA76BC4F0.jpeg', 'positive'],
#  ['C6EA0BE5-B01E-4113-B194-18D956675E25.jpeg', 'positive'],
#  ['7EF28E12-F628-4BEC-A8C5-E6277C2E4F60.png', 'positive'],
#  ['41591_2020_819_Fig1_HTML.webp-day5.png', 'positive'],
#  ['41591_2020_819_Fig1_HTML.webp-day10.png', 'positive'],
#  ['5e6dd879fde9502400e58b2f.jpeg', 'positive'],
#  ['covid-19-pneumonia-19.jpg', 'positive'],
#  ['kjr-21-e25-g001-l-a.jpg', 'positive'],
#  ['03BF7561-A9BA-4C3C-B8A0-D3E585F73F3C.jpeg', 'positive'],
#  ['353889E0-A1E8-4F9E-A0B8-F24F36BCFBFB.jpeg', 'positive'],
#  ['figure1-5e73d7ae897e27ff066a30cb-98.jpeg', 'positive'],
#  ['figure1-5e75d0940b71e1b702629659-98-right.jpeg', 'positive'],
#  ['figure1-5e71be566aa8714a04de3386-98-left.jpeg', 'positive'],
#  ['1F6343EE-AFEC-4B7D-97F5-62797EE18767.jpeg', 'positive'],
#  ['5A78BCA9-5B7A-440D-8A4E-AE7710EA6EAD.jpeg', 'positive'],
#  ['2B8649B2-00C4-4233-85D5-1CE240CF233B.jpeg', 'positive'],
#  ['2966893D-5DDF-4B68-9E2B-4979D5956C8E.jpeg', 'positive'],
#  ['covid-19-pneumonia-30-PA.jpg', 'positive'],
#  ['58cb9263f16e94305c730685358e4e_jumbo.jpeg', 'positive'],
#  ['9fdd3c3032296fd04d2cad5d9070d4_jumbo.jpeg', 'positive'],
#  ['covid-19-pneumonia-rapidly-progressive-admission.jpg', 'positive'],
#  ['covid-19-pneumonia-rapidly-progressive-12-hours.jpg', 'positive'],
#  ['covid-19-pneumonia-rapidly-progressive-3-days.jpg', 'positive'],
#  ['covid-19-infection-exclusive-gastrointestinal-symptoms-pa.png', 'positive'],
#  ['covid-19-pneumonia-28.png', 'positive'],
#  ['1.CXRCTThoraximagesofCOVID-19fromSingapore.pdf-000-fig1a.png', 'positive'],
#  ['1.CXRCTThoraximagesofCOVID-19fromSingapore.pdf-000-fig1b.png', 'positive'],
#  ['1.CXRCTThoraximagesofCOVID-19fromSingapore.pdf-001-fig2a.png', 'positive'],
#  ['1.CXRCTThoraximagesofCOVID-19fromSingapore.pdf-001-fig2b.png', 'positive'],
#  ['1.CXRCTThoraximagesofCOVID-19fromSingapore.pdf-002-fig3a.png', 'positive'],
#  ['1.CXRCTThoraximagesofCOVID-19fromSingapore.pdf-002-fig3b.png', 'positive'],
#  ['1.CXRCTThoraximagesofCOVID-19fromSingapore.pdf-003-fig4a.png', 'positive'],
#  ['1.CXRCTThoraximagesofCOVID-19fromSingapore.pdf-003-fig4b.png', 'positive'],
#  ['covid-19-pneumonia-24-day6.jpg', 'positive'],
#  ['covid-19-pneumonia-24-day7.jpg', 'positive'],
#  ['covid-19-pneumonia-24-day12.jpg', 'positive'],
#  ['53EC07C9-5CC6-4BE4-9B6F-D7B0D72AAA7E.jpeg', 'positive'],
#  ['A7E260CE-8A00-4C5F-A7F5-27336527A981.jpeg', 'positive'],
#  ['covid-19-caso-70-1-PA.jpg', 'positive'],
#  ['covid-19-caso-70-2-APS.jpg', 'positive'],
#  ['4e43e48d52c9e2d4c6c1fb9bc1544f_jumbo.jpeg', 'positive'],
#  ['covid-19-pneumonia-53.jpg', 'positive'],
#  ['post-intubuation-pneumomediastium-and-pneumothorax-background-covid-19-pneumonia-day1.jpg',
#   'positive'],
#  ['post-intubuation-pneumomediastium-and-pneumothorax-background-covid-19-pneumonia-day6-1.jpg',
#   'positive'],
#  ['post-intubuation-pneumomediastium-and-pneumothorax-background-covid-19-pneumonia-day6-2.jpg',
#   'positive'],
#  ['post-intubuation-pneumomediastium-and-pneumothorax-background-covid-19-pneumonia-day7.jpg',
#   'positive'],
#  ['covid-19-pneumonia-49-day4.jpg', 'positive'],
#  ['covid-19-pneumonia-49-day8.jpg', 'positive'],
#  ['covid-19-pneumonia-40.jpg', 'positive'],
#  ['covid-19-pneumonia-42.jpeg', 'positive'],
#  ['da9e9aac-de8c-44c7-ba57-e7cc8e4caaba.annot.original.jpeg', 'positive'],
#  ['4ad30bc6-2da0-4f84-bc9b-62acabfd518a.annot.original.png', 'positive'],
#  ['fff49165-b22d-4bb4-b9d1-d5d62c52436c.annot.original.png', 'positive'],
#  ['radiol.2020201160.fig2a.jpeg', 'positive'],
#  ['radiol.2020201160.fig2b.jpeg', 'positive'],
#  ['radiol.2020201160.fig2c.jpeg', 'positive'],
#  ['radiol.2020201160.fig2d.jpeg', 'positive'],
#  ['radiol.2020201160.fig3a.jpeg', 'positive'],
#  ['radiol.2020201160.fig3b.jpeg', 'positive'],
#  ['radiol.2020201160.fig3c.jpeg', 'positive'],
#  ['radiol.2020201160.fig3d.jpeg', 'positive'],
#  ['radiol.2020201160.fig6b.jpeg', 'positive'],
#  ['ryct.2020003.fig2-a.png', 'positive'],
#  ['ryct.2020003.fig2-b.png', 'positive'],
#  ['ryct.2020003.fig2-c.png', 'positive'],
#  ['radiol.2020200274.fig3d.png', 'positive'],
#  ['covid-19-pneumonia-8.jpg', 'positive'],
#  ['covid-19-pneumonia-22-day1-pa.png', 'positive'],
#  ['covid-19-pneumonia-22-day2-pa.png', 'positive'],
#  ['covid-19-pneumonia-34.png', 'positive'],
#  ['covid-19-pneumonia-38-pa.jpg', 'positive'],
#  ['covid-19-pneumonia-35-1.jpg', 'positive'],
#  ['covid-19-pneumonia-35-2.jpg', 'positive'],
#  ['covid-19-pneumonia-41-day-0.jpg', 'positive'],
#  ['covid-19-pneumonia-41-day-2.jpg', 'positive'],
#  ['covid-19-pneumonia-58-day-3.jpg', 'positive'],
#  ['covid-19-pneumonia-58-day-7.jpg', 'positive'],
#  ['covid-19-pneumonia-58-day-9.jpg', 'positive'],
#  ['covid-19-pneumonia-58-day-10.jpg', 'positive'],
#  ['covid-19-pneumonia-bilateral.jpg', 'positive'],
#  ['16663_1_1.jpg', 'positive'],
#  ['16660_1_1.jpg', 'positive'],
#  ['16660_2_1.jpg', 'positive'],
#  ['16660_3_1.jpg', 'positive'],
#  ['16660_4_1.jpg', 'positive'],
#  ['16660_5_1.jpg', 'positive'],
#  ['16691_1_1.jpg', 'positive'],
#  ['16674_1_1.jpg', 'positive'],
#  ['16672_1_1.jpg', 'positive'],
#  ['16669_1_1.jpeg', 'positive'],
#  ['16669_3_1.jpeg', 'positive'],
#  ['16664_1_1.jpg', 'positive'],
#  ['ajr.20.23034.pdf-001.png', 'positive'],
#  ['ajr.20.23034.pdf-003.png', 'positive'],
#  ['yxppt-2020-02-19_00-51-27_287214-day8.jpg', 'positive'],
#  ['yxppt-2020-02-19_00-51-27_287214-day10.jpg', 'positive'],
#  ['yxppt-2020-02-19_00-51-27_287214-day12.jpg', 'positive'],
#  ['ae6c954c0039de4b5edee53865ffee43-e6c8-0.jpg', 'positive'],
#  ['6b3bdbc31f65230b8cdcc3cef5f8ba8a-40ac-0.jpg', 'positive'],
#  ['67d668e570c242404ba82c7cbe2ca8f2-05be-0.jpg', 'positive'],
#  ['67d668e570c242404ba82c7cbe2ca8f2-0015-0.jpg', 'positive'],
#  ['AR-1.jpg', 'positive'],
#  ['AR-2.jpg', 'positive'],
#  ['2-chest-filmc.jpg', 'positive'],
#  ['paving.jpg', 'positive'],
#  ['7-fatal-covid19.jpg', 'positive'],
#  ['extubation-1.jpg', 'positive'],
#  ['extubation-4.jpg', 'positive'],
#  ['extubation-8.jpg', 'positive'],
#  ['extubation-13.jpg', 'positive'],
#  ['16724_1_1.jpg', 'positive'],
#  ['16673_2_1.jpg', 'positive'],
#  ['16708_1_1.jpg', 'positive'],
#  ['16708_4_1.jpg', 'positive'],
#  ['16708_5_1.jpg', 'positive'],
#  ['16706_1_1.png', 'positive'],
#  ['case_71_figura1.png', 'positive'],
#  ['case_72_RX-TORACE1.jpg', 'positive'],
#  ['case_76_1-3.png', 'positive'],
#  ['covid-19-pneumonia-101.png', 'positive'],
#  ['covid-19-pneumonia-93.png', 'positive'],
#  ['covid-19-pneumonia-progression-and-regression-day1.jpg', 'positive'],
#  ['covid-19-pneumonia-progression-and-regression-day6.jpg', 'positive'],
#  ['covid-19-pneumonia-progression-and-regression-day11.jpg', 'positive'],
#  ['covid-19-pneumonia-progression-and-regression-day13.jpg', 'positive'],
#  ['covid-19-pneumonia-progression-and-regression-day20.jpg', 'positive'],
#  ['covid-19-pneumonia-progression-and-regression-day24.jpg', 'positive'],
#  ['covid-19-pneumonia-progression-and-regression-day28.jpg', 'positive'],
#  ['16747_1_1.jpg', 'positive'],
#  ['16747_2_1.jpg', 'positive'],
#  ['16747_3_1.jpg', 'positive'],
#  ['16745_4_1.png', 'positive'],
#  ['16745_5_1.png', 'positive'],
#  ['16745_7_1.png', 'positive'],
#  ['16744_1_1.jpg', 'positive'],
#  ['b343e657.jpg', 'positive'],
#  ['53c9be49.jpg', 'positive'],
#  ['bd3ceeb6.jpg', 'positive'],
#  ['2168a917.jpg', 'positive'],
#  ['61bc50d1.jpg', 'positive'],
#  ['87d50e40.jpg', 'positive'],
#  ['5f619d7e.jpg', 'positive'],
#  ['a38e1877.jpg', 'positive'],
#  ['4d98e1de.jpg', 'positive'],
#  ['80b5f00f.jpg', 'positive'],
#  ['00870a9c.jpg', 'positive'],
#  ['35b446ce.jpg', 'positive'],
#  ['90070cbc.jpg', 'positive'],
#  ['c0f74558.jpg', 'positive'],
#  ['f6575117.jpg', 'positive'],
#  ['ac4f6e4e.jpg', 'positive'],
#  ['2cd63b76.jpg', 'positive'],
#  ['262a70ca.jpg', 'positive'],
#  ['19abe1f3.jpg', 'positive'],
#  ['bb0e626a.jpg', 'positive'],
#  ['441c9cdd.jpg', 'positive'],
#  ['f64132c8.jpg', 'positive'],
#  ['bfefde5d.jpg', 'positive'],
#  ['9d36404d.jpg', 'positive'],
#  ['3dedeb92.jpg', 'positive'],
#  ['483f2ad8.jpg', 'positive'],
#  ['bd10d5e2.jpg', 'positive'],
#  ['a2eba651.jpg', 'positive'],
#  ['f8335316.jpg', 'positive'],
#  ['4fed5061.jpg', 'positive'],
#  ['3b46de94.jpg', 'positive'],
#  ['d9d6ca9a.jpg', 'positive'],
#  ['a361d7b7.jpg', 'positive'],
#  ['d680397c.jpg', 'positive'],
#  ['d6494b39.jpg', 'positive'],
#  ['4fcafe41.jpg', 'positive'],
#  ['1880e301.jpg', 'positive'],
#  ['ee2d1bf6.jpg', 'positive'],
#  ['3248cc61.jpg', 'positive'],
#  ['3fd337c1.jpg', 'positive'],
#  ['887db78f.jpg', 'positive'],
#  ['527321ee.jpg', 'positive'],
#  ['333932bd.jpg', 'positive'],
#  ['e1446fe8.jpg', 'positive'],
#  ['c828e894.jpg', 'positive'],
#  ['24035bda.jpg', 'positive'],
#  ['08d780ae.jpg', 'positive'],
#  ['cb706009.jpg', 'positive'],
#  ['e1a4f870.jpg', 'positive'],
#  ['1663b242.jpg', 'positive'],
#  ['4c0fcf57.jpg', 'positive'],
#  ['a47dc73e.jpg', 'positive'],
#  ['d7f2ee0f.jpg', 'positive'],
#  ['db96a050.jpg', 'positive'],
#  ['d009d61f.jpg', 'positive'],
#  ['7afaaccc.jpg', 'positive'],
#  ['ec083e35.jpg', 'positive'],
#  ['c601f50d.jpg', 'positive'],
#  ['8da14fff.jpg', 'positive'],
#  ['1052b0fe.jpg', 'positive'],
#  ['1f8a4a54.jpg', 'positive'],
#  ['21982772.jpg', 'positive'],
#  ['19073f37.jpg', 'positive'],
#  ['8fc103ca.jpg', 'positive'],
#  ['86d19bba.jpg', 'positive'],
#  ['f6d980a0.jpg', 'positive'],
#  ['b9673e89.jpg', 'positive'],
#  ['1d435a4b.jpg', 'positive'],
#  ['0a7faa2a.jpg', 'positive'],
#  ['b39f5cf9.jpg', 'positive'],
#  ['5782ae15.jpg', 'positive'],
#  ['865336ed.jpg', 'positive'],
#  ['436a6348.jpg', 'positive'],
#  ['48c4542c.jpg', 'positive'],
#  ['c3829ecb.jpg', 'positive'],
#  ['5acb8ac5.jpg', 'positive'],
#  ['a8ac1969.jpg', 'positive'],
#  ['82a78c13.jpg', 'positive'],
#  ['90986ce4.jpg', 'positive'],
#  ['nejmoa2001017_f1-a.png', 'positive'],
#  ['nejmoa2001017_f1-b.png', 'positive'],
#  ['68_2020_1364_Fig1_HTML-a.png', 'positive'],
#  ['68_2020_1364_Fig1_HTML-b.png', 'positive'],
#  ['68_2020_1364_Fig1_HTML-c.png', 'positive'],
#  ['270_2020_2470_Fig1_HTML-a.png', 'positive'],
#  ['270_2020_2470_Fig1_HTML-b.png', 'positive'],
#  ['296_2020_4584_Fig2_HTML-a.png', 'positive'],
#  ['296_2020_4584_Fig2_HTML-b.png', 'positive'],
#  ['296_2020_4584_Fig2_HTML-c.png', 'positive'],
#  ['701_2020_4374_Fig2_HTML.png', 'positive'],
#  ['nejmoa2004500_f1-a.png', 'positive'],
#  ['nejmoa2004500_f1-b.png', 'positive'],
#  ['11547_2020_1200_Fig3_HTML-a.png', 'positive'],
#  ['11547_2020_1200_Fig3_HTML-b.png', 'positive'],
#  ['11547_2020_1200_Fig3_HTML-c.png', 'positive'],
#  ['11547_2020_1200_Fig2_HTML-a.png', 'positive'],
#  ['11547_2020_1200_Fig2_HTML-b.png', 'positive'],
#  ['11547_2020_1202_Fig1_HTML-a.png', 'positive'],
#  ['11547_2020_1202_Fig1_HTML-b.png', 'positive'],
#  ['11547_2020_1203_Fig1_HTML-a.png', 'positive'],
#  ['11547_2020_1203_Fig1_HTML-b.png', 'positive'],
#  ['11547_2020_1203_Fig1_HTML-c.png', 'positive'],
#  ['11547_2020_1203_Fig1_HTML-d.png', 'positive'],
#  ['11547_2020_1203_Fig2_HTML-a.png', 'positive'],
#  ['11547_2020_1203_Fig2_HTML-b.png', 'positive'],
#  ['11547_2020_1203_Fig2_HTML-c.png', 'positive'],
#  ['11547_2020_1203_Fig2_HTML-d.png', 'positive'],
#  ['1-s2.0-S0735675720302746-gr1_lrg.jpg', 'positive'],
#  ['1-s2.0-S0196070920301691-gr3_lrg.jpg', 'positive'],
#  ['10.1016-slash-j.anl.2020.04.002-a.png', 'positive'],
#  ['10.1016-slash-j.anl.2020.04.002-b.png', 'positive'],
#  ['10.1016-slash-j.anl.2020.04.002-c.png', 'positive'],
#  ['1-s2.0-S0889159120306851-gr2b_lrg.jpg', 'positive'],
#  ['10.1016-slash-j.cardfail.2020.04.007-a.png', 'positive'],
#  ['10.1016-slash-j.cardfail.2020.04.007-b.png', 'positive'],
#  ['10.1016-slash-j.chest.2020.04.024.png', 'positive'],
#  ['1-s2.0-S1931312820301852-gr1_lrg-a.png', 'positive'],
#  ['1-s2.0-S1931312820301852-gr1_lrg-b.png', 'positive'],
#  ['1-s2.0-S1931312820301852-gr1_lrg-c.png', 'positive'],
#  ['1-s2.0-S1521661620303314-gr1_lrg-a.png', 'positive'],
#  ['1-s2.0-S1521661620303314-gr1_lrg-b.png', 'positive'],
#  ['10.1016-slash-j.crad.2020.04.002-a.png', 'positive'],
#  ['10.1016-slash-j.crad.2020.04.002-b.png', 'positive'],
#  ['10.1016-slash-j.healun.2020.04.004.jpg', 'positive'],
#  ['10.1016-slash-j.hrcr.2020.04.015-a.png', 'positive'],
#  ['10.1016-slash-j.hrcr.2020.04.015-b.png', 'positive'],
#  ['10.1016-slash-j.hrcr.2020.04.015-fig3-b.png', 'positive'],
#  ['1-s2.0-S2214250920300706-gr1_lrg.jpg', 'positive'],
#  ['1-s2.0-S2214250920300706-gr2_lrg.jpg', 'positive'],
#  ['1-s2.0-S2214250920300706-gr5_lrg.jpg', 'positive'],
#  ['1-s2.0-S2214250920300834-gr1_lrg-b.png', 'positive'],
#  ['1-s2.0-S2214250920300834-gr1_lrg-c.png', 'positive'],
#  ['1-s2.0-S2213716520301168-gr1_lrg-a.png', 'positive'],
#  ['1-s2.0-S2213716520301168-gr1_lrg-b.png', 'positive'],
#  ['10.1016-slash-j.jhin.2020.03.036.png', 'positive'],
#  ['1-s2.0-S1341321X20301124-gr3_lrg-c.png', 'positive'],
#  ['1-s2.0-S1341321X20301124-gr3_lrg-d.png', 'positive'],
#  ['1-s2.0-S1341321X20301124-gr3_lrg-e.png', 'positive'],
#  ['1-s2.0-S1684118220300372-gr1_lrg-a.png', 'positive'],
#  ['1-s2.0-S1684118220300372-gr1_lrg-b.png', 'positive'],
#  ['1-s2.0-S0085253820303616-gr1_lrg-a.png', 'positive'],
#  ['1-s2.0-S0085253820303616-gr1_lrg-b.png', 'positive'],
#  ['1-s2.0-S2387020620301959-gr4_lrg-a.png', 'positive'],
#  ['1-s2.0-S2387020620301959-gr4_lrg-b.png', 'positive'],
#  ['1-s2.0-S2387020620301959-gr4_lrg-c.png', 'positive'],
#  ['1-s2.0-S2531043720300921-gr1.png', 'positive'],
#  ['fx1_lrg.jpg', 'positive'],
#  ['gr2_lrg-a.png', 'positive'],
#  ['gr2_lrg-b.png', 'positive'],
#  ['gr2_lrg-c.png', 'positive'],
#  ['1-s2.0-S1059131120301151-gr2-f.png', 'positive'],
#  ['41379_2020_536_Fig2_HTML-c1.png', 'positive'],
#  ['41379_2020_536_Fig2_HTML-c2.png', 'positive'],
#  ['afaa068f1.png', 'positive'],
#  ['12941_2020_358_Fig1_HTML.jpg', 'positive'],
#  ['40779_2020_233_Fig2_HTML-a.png', 'positive'],
#  ['41182_2020_203_Fig3_HTML.jpg', 'positive'],
#  ['41182_2020_203_Fig4_HTML.jpg', 'positive'],
#  ['41182_2020_203_Fig5_HTML.jpg', 'positive'],
#  ['tpmd200203f2-a.png', 'positive'],
#  ['tpmd200203f2-b.png', 'positive'],
#  ['tpmd200203f2-c.png', 'positive'],
#  ['BMJ-37-163-g1.jpg', 'positive'],
#  ['thnov10p5641g006-c.png', 'positive'],
#  ['lightbox_78f27a80685411ea93cde791fb7cd172-CXR.png', 'positive'],
#  ['article_river_e4d185c06e3511eaa2321d8ab357a1de-c1mn.png', 'positive'],
#  ['article_river_c79329e06dff11eab69c95940c7c0d00-CXR-D1-COVID19.png',
#   'positive'],
#  ['article_river_de7471906e0011eabe5f9363acaf45c4-covid-cxr-2.png',
#   'positive'],
#  ['article_river_1a00a3c07ea311eab70491c6fb93d336-figure-2.png', 'positive'],
#  ['article_river_2a361d607ea311ea95dbcf0c95d13492-figure-4.png', 'positive'],
#  ['covid-19-caso-82-1-8.png', 'positive'],
#  ['covid-19-caso-85-1-9.png', 'positive'],
#  ['covid-19-caso-85-4-6.png', 'positive'],
#  ['covid-19-caso-85-5-4.png', 'positive'],
#  ['covid-19-caso-86-Rx-torace-1.jpg', 'positive'],
#  ['covid-19-caso-86-RX-Torace-2.jpg', 'positive'],
#  ['covid-19-caso-91-1-12.png', 'positive'],
#  ['covid-19-caso-94-1-14.png', 'positive'],
#  ['covid-19-caso-95-1-15.png', 'positive'],
#  ['covid-19-caso-95-3-14.png', 'positive'],
#  ['covid-19-caso-99-1-19.png', 'positive'],
#  ['covid-19-caso-111-1-21.png', 'positive'],
#  ['08ed451c576ee00935ee178ec85c57_jumbo-1.jpeg', 'positive'],
#  ['e73d6e89fcd781b8afd159cf533358_jumbo-1.jpeg', 'positive'],
#  ['1141cc2b8b9cc394becce5d978b5a7_jumbo.jpeg', 'positive'],
#  ['6770dac454c45c86bc6c2d6193b177_jumbo.jpeg', 'positive'],
#  ['071d06607edf81d70c940e043bce34_jumbo.jpeg', 'positive'],
#  ['0a6c60063b4bae4de001caaba306d1_jumbo.jpeg', 'positive'],
#  ['5ed7d0109672bdd3d58a7db7841f6a_jumbo.jpeg', 'positive'],
#  ['fedd6c94d5dbd12d88c81a1020a3e4_jumbo.jpeg', 'positive'],
#  ['14d81f378173b86cc53f21d2d67040_jumbo.jpeg', 'positive'],
#  ['3eaf15de91d4ff55e6fb0e04cadb81_jumbo.jpeg', 'positive'],
#  ['a1fec23b293dfe7876660cb7acce43_jumbo.jpeg', 'positive'],
#  ['78b60346d1b3bce85353b6dc462d75_jumbo.jpeg', 'positive'],
#  ['c17cdd3972b233b97770bb57f7bba6_jumbo.jpeg', 'positive'],
#  ['f44373474437c99b2740062c914438_jumbo.jpeg', 'positive'],
#  ['b0f1684d1ee90dc09deef015e29dae_jumbo.jpeg', 'positive'],
#  ['3b66f98f30636b2e1fb42c1d0f18a8_jumbo.jpeg', 'positive'],
#  ['50e51fcefaa760d0757eeae6eb0858_jumbo.jpeg', 'positive'],
#  ['8eda8be6369c87e0899f6d1642e97b_jumbo.jpeg', 'positive'],
#  ['2d8a60a26381b256a5a6373708950e_jumbo.jpeg', 'positive'],
#  ['2eadbbb367a0366d8c34350d083a83_jumbo.jpeg', 'positive'],
#  ['7867b1aa2d1241045c917f07a9e683_jumbo.jpeg', 'positive'],
#  ['16755_3_1.jpg', 'positive'],
#  ['1-s2.0-S2387020620301959-gr3_lrg-a.png', 'positive'],
#  ['ansu-publish-ahead-of-print-10.1097.sla.0000000000003955-g001-a.png',
#   'positive'],
#  ['ansu-publish-ahead-of-print-10.1097.sla.0000000000003955-g001-c.png',
#   'positive'],
#  ['ansu-publish-ahead-of-print-10.1097.sla.0000000000003955-g001-d.png',
#   'positive'],
#  ['ansu-publish-ahead-of-print-10.1097.sla.0000000000003955-g001-f.png',
#   'positive'],
#  ['aqaa062i0002-a.png', 'positive'],
#  ['aqaa062i0002-b.png', 'positive'],
#  ['be835db3a56b5f76d607061dbb82a5_jumbo.jpeg', 'positive'],
#  ['3c48faa5dc2f1540fda696bae045ba_jumbo.jpeg', 'positive'],
#  ['447d65b38231a1031586b304bc5837_jumbo.jpeg', 'positive'],
#  ['81af553601a1bc1fdf81c99436a50b_jumbo.jpeg', 'positive'],
#  ['f46a9bfc7222e61e099a25ab9267da_jumbo.jpeg', 'positive'],
#  ['882fd7ec99b523aead995d78f3129f_jumbo.jpeg', 'positive'],
#  ['4cb2f877226f5e02b3064e1e52075f_jumbo.jpeg', 'positive'],
#  ['556e19b9d38e2199dfa8722ddff25f_jumbo.jpeg', 'positive'],
#  ['8781ac6b9589f3646d2bbfff8f9015_jumbo.jpeg', 'positive'],
#  ['078d2e0b3e4fec1d603efb0e818c31_jumbo.jpeg', 'positive'],
#  ['c94ef38ddb2d94aa11828716777139_jumbo.jpeg', 'positive'],
#  ['16953_1_1.jpg', 'positive'],
#  ['16953_3_1.jpg', 'positive'],
#  ['16953_4_1.jpg', 'positive'],
#  ['16953_5_1.jpg', 'positive'],
#  ['16892_2_1.png', 'positive'],
#  ['16883_1_1.png', 'positive'],
#  ['2edb88df42cab5e5fbc18b3965e0bd_jumbo.jpeg', 'positive'],
#  ['16858_1_1.png', 'positive'],
#  ['16858_3_1.png', 'positive'],
#  ['16865_1_1.jpg', 'positive'],
#  ['COVID-00001.jpg', 'positive'],
#  ['COVID-00004.jpg', 'positive'],
#  ['COVID-00006.jpg', 'positive'],
#  ['COVID-00008.jpg', 'positive'],
#  ['COVID-00009.jpg', 'positive'],
#  ['COVID-00011.jpg', 'positive'],
#  ['COVID-00012.jpg', 'positive'],
#  ['COVID-00015a.png', 'positive'],
#  ['COVID-00015b.png', 'positive'],
#  ['COVID-00016.jpg', 'positive'],
#  ['COVID-00017.jpg', 'positive'],
#  ['COVID-00018.jpg', 'positive'],
#  ['COVID-00020.jpg', 'positive'],
#  ['COVID-00021.jpg', 'positive'],
#  ['COVID-00022.jpg', 'positive'],
#  ['COVID-00024.jpg', 'positive'],
#  ['COVID-00039a.jpg', 'positive'],
#  ['COVID-00039b.jpg', 'positive'],
#  ['COVID-00039c.jpg', 'positive'],
#  ['COVID-00043a.jpg', 'positive'],
#  ['COVID-00043b.jpg', 'positive'],
#  ['COVID-00045.png', 'positive'],
#  ['COVID-00046.png', 'positive'],
#  ['COVID-00048.png', 'positive'],
#  ['CR.1.2.840.113564.1722810170.20200318082923328940.1003000225002.png',
#   'positive'],
#  ['CR.1.2.840.113564.1722810170.20200320011259312440.1003000225002.png',
#   'positive'],
#  ['CR.1.2.840.113564.1722810170.20200320170359875720.1003000225002.png',
#   'positive'],
#  ['CR.1.2.840.113564.1722810170.20200322160314468140.1003000225002.png',
#   'positive'],
#  ['CR.1.2.840.113564.1722810170.20200324165957625920.1003000225002.png',
#   'positive'],
#  ['CR.1.2.840.113564.1722810170.20200326010813390400.1003000225002.png',
#   'positive'],
#  ['CR.1.2.840.113564.1722810170.20200327151518468570.1003000225002.png',
#   'positive'],
#  ['CR.1.2.840.113564.1722810170.20200327154027828590.1003000225002.png',
#   'positive'],
#  ['CR.1.2.840.113564.1722810170.20200405065153640420.1003000225002.png',
#   'positive'],
#  ['CR.1.2.840.113564.1722810170.20200408094743609850.1003000225002.png',
#   'positive'],
#  ['CR.1.2.840.113564.1722810170.20200416105826265860.1003000225002.png',
#   'positive'],
#  ['CR.1.2.840.113564.1722810170.20200416110930703890.1003000225002.png',
#   'positive'],
#  ['CR.1.2.840.113564.192168196.2020040116564476574.1203801020003.png',
#   'positive'],
#  ['DX.1.2.840.113564.1722810162.20200322102521497410.1203801020003.png',
#   'positive'],
#  ['DX.1.2.840.113564.1722810162.202003241226081857.1203801020003.png',
#   'positive'],
#  ['DX.1.2.840.113564.1722810162.20200325102716421950.1203801020003.png',
#   'positive'],
#  ['DX.1.2.840.113564.1722810162.20200325125743092120.1203801020003.png',
#   'positive'],
#  ['DX.1.2.840.113564.1722810162.20200326123403551130.1203801020003.png',
#   'positive'],
#  ['DX.1.2.840.113564.1722810162.20200326123552855170.1203801020003.png',
#   'positive'],
#  ['DX.1.2.840.113564.1722810162.20200327160432430120.1203801020003.png',
#   'positive'],
#  ['DX.1.2.840.113564.1722810162.20200331100140006240.1203801020003.png',
#   'positive'],
#  ['DX.1.2.840.113564.1722810162.20200401122015054240.1203801020003.png',
#   'positive'],
#  ['DX.1.2.840.113564.1722810162.20200405112431725920.1203801020003.png',
#   'positive'],
#  ['DX.1.2.840.113564.1722810162.20200405142816863980.1203801020003.png',
#   'positive'],
#  ['DX.1.2.840.113564.1722810162.20200420135116095500.1203801020003.png',
#   'positive'],
#  ['COVID(1).png', 'positive'],
#  ['COVID(2).png', 'positive'],
#  ['COVID(3).png', 'positive'],
#  ['COVID(4).png', 'positive'],
#  ['COVID(5).png', 'positive'],
#  ['COVID(6).png', 'positive'],
#  ['COVID(7).png', 'positive'],
#  ['COVID(8).png', 'positive'],
#  ['COVID(9).png', 'positive'],
#  ['COVID(10).png', 'positive'],
#  ['COVID(11).png', 'positive'],
#  ['COVID(12).png', 'positive'],
#  ['COVID(13).png', 'positive'],
#  ['COVID(14).png', 'positive'],
#  ['COVID(15).png', 'positive'],
#  ['COVID(16).png', 'positive'],
#  ['COVID(17).png', 'positive'],
#  ['COVID(18).png', 'positive'],
#  ['COVID(19).png', 'positive'],
#  ['COVID(20).png', 'positive'],
#  ['COVID(21).png', 'positive'],
#  ['COVID(22).png', 'positive'],
#  ['COVID(23).png', 'positive'],
#  ['COVID(24).png', 'positive'],
#  ['COVID(25).png', 'positive'],
#  ['COVID(26).png', 'positive'],
#  ['COVID(27).png', 'positive'],
#  ['COVID(28).png', 'positive'],
#  ['COVID(29).png', 'positive'],
#  ['COVID(30).png', 'positive'],
#  ['COVID(31).png', 'positive'],
#  ['COVID(32).png', 'positive'],
#  ['COVID(33).png', 'positive'],
#  ['COVID(34).png', 'positive'],
#  ['COVID(35).png', 'positive'],
#  ['COVID(36).png', 'positive'],
#  ['COVID(37).png', 'positive'],
#  ['COVID(38).png', 'positive'],
#  ['COVID(39).png', 'positive'],
#  ['COVID(40).png', 'positive'],
#  ['COVID(41).png', 'positive'],
#  ['COVID(42).png', 'positive'],
#  ['COVID(43).png', 'positive'],
#  ['COVID(44).png', 'positive'],
#  ['COVID(45).png', 'positive'],
#  ['COVID(46).png', 'positive'],
#  ['COVID(47).png', 'positive'],
#  ['COVID(48).png', 'positive'],
#  ['COVID(49).png', 'positive'],
#  ['COVID(50).png', 'positive'],
#  ['COVID(51).png', 'positive'],
#  ['COVID(52).png', 'positive'],
#  ['COVID(53).png', 'positive'],
#  ['COVID(54).png', 'positive'],
#  ['COVID(55).png', 'positive'],
#  ['COVID(56).png', 'positive'],
#  ['COVID(57).png', 'positive'],
#  ['COVID(58).png', 'positive'],
#  ['COVID(59).png', 'positive'],
#  ['COVID(60).png', 'positive'],
#  ['COVID(61).png', 'positive'],
#  ['COVID(62).png', 'positive'],
#  ['COVID(63).png', 'positive'],
#  ['COVID(64).png', 'positive'],
#  ['COVID(65).png', 'positive'],
#  ['COVID(66).png', 'positive'],
#  ['COVID(67).png', 'positive'],
#  ['COVID(68).png', 'positive'],
#  ['COVID(69).png', 'positive'],
#  ['COVID(71).png', 'positive'],
#  ['COVID(73).png', 'positive'],
#  ['COVID(74).png', 'positive'],
#  ['COVID(75).png', 'positive'],
#  ['COVID(76).png', 'positive'],
#  ['COVID(78).png', 'positive'],
#  ['COVID(79).png', 'positive'],
#  ['COVID(80).png', 'positive'],
#  ['COVID(82).png', 'positive'],
#  ['COVID(83).png', 'positive'],
#  ['COVID(84).png', 'positive'],
#  ['COVID(85).png', 'positive'],
#  ['COVID(86).png', 'positive'],
#  ['COVID(88).png', 'positive'],
#  ['COVID(89).png', 'positive'],
#  ['COVID(90).png', 'positive'],
#  ['COVID(91).png', 'positive'],
#  ['COVID(92).png', 'positive'],
#  ['COVID(93).png', 'positive'],
#  ['COVID(96).png', 'positive'],
#  ['COVID(97).png', 'positive'],
#  ['COVID(98).png', 'positive'],
#  ['COVID(99).png', 'positive'],
#  ['COVID(100).png', 'positive'],
#  ['COVID(101).png', 'positive'],
#  ['COVID(102).png', 'positive'],
#  ['COVID(103).png', 'positive'],
#  ['COVID(104).png', 'positive'],
#  ['COVID(105).png', 'positive'],
#  ['COVID(108).png', 'positive'],
#  ['COVID(109).png', 'positive'],
#  ['COVID(110).png', 'positive'],
#  ['COVID(111).png', 'positive'],
#  ['COVID(112).png', 'positive'],
#  ['COVID(113).png', 'positive'],
#  ['COVID(114).png', 'positive'],
#  ['COVID(115).png', 'positive'],
#  ['COVID(117).png', 'positive'],
#  ...]

# %%
import csv
# opening the csv file in 'a+' mode 
file = open('train.csv', 'a+', newline ='') 
  
# writing the data into the file 
with file:     
    write = csv.writer(file) 
    write.writerows(final_train_data)

# %%
final_test
# Out:
# [array(['ANON193',
#         'CR.1.2.840.113564.1722810170.20200418154808640220.1003000225002.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON175',
#         'CR.1.2.840.113564.192168196.2020040610405214785.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON216',
#         'DX.1.2.840.113564.1722810162.20200321192719071860.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON156',
#         'DX.1.2.840.113564.1722810162.20200324090442116980.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON141',
#         'DX.1.2.840.113564.1722810162.20200324173135171450.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON128',
#         'DX.1.2.840.113564.1722810162.20200325035519587850.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON120',
#         'DX.1.2.840.113564.1722810162.20200325235118699920.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON6',
#         'DX.1.2.840.113564.1722810162.20200327135133580890.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON186',
#         'DX.1.2.840.113564.1722810162.202003271502385806.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON2',
#         'DX.1.2.840.113564.1722810162.20200328190915750960.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON168',
#         'DX.1.2.840.113564.1722810162.20200402222138430240.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON143',
#         'DX.1.2.840.113564.1722810162.20200403095438767300.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON131',
#         'DX.1.2.840.113564.1722810162.202004031554257618.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON28',
#         'DX.1.2.840.113564.1722810162.20200403173403510160.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON194',
#         'DX.1.2.840.113564.1722810162.20200407205007081240.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON152',
#         'DX.1.2.840.113564.1722810162.20200417111010040980.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON15',
#         'DX.1.2.840.113564.1722810162.20200417170403543170.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON65',
#         'DX.1.2.840.113564.1722810162.20200420091034687240.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON148',
#         'DX.1.2.840.113564.1722810162.20200420124516732440.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['ANON93',
#         'DX.1.2.840.113564.1722810162.202004201905117341.1203801020003.png',
#         'negative', 'actmed'], dtype='<U67'),
#  array(['19', '1-s2.0-S0929664620300449-gr2_lrg-a.jpg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['19', '1-s2.0-S0929664620300449-gr2_lrg-b.jpg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['19', '1-s2.0-S0929664620300449-gr2_lrg-c.jpg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['19', '1-s2.0-S0929664620300449-gr2_lrg-d.jpg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['20', 'covid-19-pneumonia-15-PA.jpg', 'COVID-19', 'cohen'],
#        dtype='<U91'),
#  array(['36', '8FDE8DBA-CFBD-4B4C-B1A4-6F36A93B7E87.jpeg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['36', '9C34AF49-E589-44D5-92D3-168B3B04E4A6.jpeg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['42', '1B734A89-A1BF-49A8-A1D3-66FAFA4FAC5D.jpeg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['86', 'B2D20576-00B7-4519-A415-72DE29C90C34.jpeg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['86', '6C94A287-C059-46A0-8600-AFB95F4727B7.jpeg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['94', '6b44464d-73a7-4cf3-bbb6-ffe7168300e3.annot.original.jpeg',
#         'COVID-19', 'cohen'], dtype='<U91'),
#  array(['97',
#         'covid-19-rapidly-progressive-acute-respiratory-distress-syndrome-ards-admission.jpg',
#         'COVID-19', 'cohen'], dtype='<U91'),
#  array(['97',
#         'covid-19-rapidly-progressive-acute-respiratory-distress-syndrome-ards-day-1.jpg',
#         'COVID-19', 'cohen'], dtype='<U91'),
#  array(['97',
#         'covid-19-rapidly-progressive-acute-respiratory-distress-syndrome-ards-day-2.jpg',
#         'COVID-19', 'cohen'], dtype='<U91'),
#  array(['97',
#         'covid-19-rapidly-progressive-acute-respiratory-distress-syndrome-ards-day-3.jpg',
#         'COVID-19', 'cohen'], dtype='<U91'),
#  array(['117', 'covid-19-pneumonia-evolution-over-a-week-1-day0-PA.jpg',
#         'COVID-19', 'cohen'], dtype='<U91'),
#  array(['117', 'covid-19-pneumonia-evolution-over-a-week-1-day3.jpg',
#         'COVID-19', 'cohen'], dtype='<U91'),
#  array(['117', 'covid-19-pneumonia-evolution-over-a-week-1-day4.jpg',
#         'COVID-19', 'cohen'], dtype='<U91'),
#  array(['117', 'covid-19-pneumonia-evolution-over-a-week-1-day6.jpg',
#         'COVID-19', 'cohen'], dtype='<U91'),
#  array(['132', 'covid-19-pneumonia-23-day1.jpg', 'COVID-19', 'cohen'],
#        dtype='<U91'),
#  array(['132', 'covid-19-pneumonia-23-day3.jpg', 'COVID-19', 'cohen'],
#        dtype='<U91'),
#  array(['132', 'covid-19-pneumonia-23-day9.jpg', 'COVID-19', 'cohen'],
#        dtype='<U91'),
#  array(['138',
#         'RX-torace-a-letto-del-paziente-in-unica-proiezione-AP-1-1.jpeg',
#         'COVID-19', 'cohen'], dtype='<U91'),
#  array(['144', 'covid-19-pneumonia-43-day0.jpeg', 'COVID-19', 'cohen'],
#        dtype='<U91'),
#  array(['144', 'covid-19-pneumonia-43-day2.jpeg', 'COVID-19', 'cohen'],
#        dtype='<U91'),
#  array(['150', 'figure1-5e7c1b8d98c29ab001275405-98.jpeg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['150', 'figure1-5e7c1b8d98c29ab001275405-98-later.jpeg',
#         'COVID-19', 'cohen'], dtype='<U91'),
#  array(['163', 'covid-19-pneumonia-20-pa-on-admission.jpg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['163', 'covid-19-pneumonia-20.jpg', 'COVID-19', 'cohen'],
#        dtype='<U91'),
#  array(['169', 'covid-19-pneumonia-44-day-0.jpeg', 'COVID-19', 'cohen'],
#        dtype='<U91'),
#  array(['169', 'covid-19-pneumonia-44-day-8.jpeg', 'COVID-19', 'cohen'],
#        dtype='<U91'),
#  array(['174', 'covid-19-pneumonia-mild.JPG', 'COVID-19', 'cohen'],
#        dtype='<U91'),
#  array(['175', 'covid-19-pneumonia-67.jpeg', 'COVID-19', 'cohen'],
#        dtype='<U91'),
#  array(['179', '16654_1_1.png', 'COVID-19', 'cohen'], dtype='<U91'),
#  array(['179', '16654_2_1.jpg', 'COVID-19', 'cohen'], dtype='<U91'),
#  array(['179', '16654_4_1.jpg', 'COVID-19', 'cohen'], dtype='<U91'),
#  array(['190', '88de9d8c39e946abd495b37cd07d89e5-0666-0.jpg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['190', '88de9d8c39e946abd495b37cd07d89e5-2ee6-0.jpg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['190', '88de9d8c39e946abd495b37cd07d89e5-6531-0.jpg', 'COVID-19',
#         'cohen'], dtype='<U91'),
#  array(['COVID-00025', 'COVID-00025.jpg', 'COVID-19', 'fig1'], dtype='<U91'),
#  array(['COVID-00026', 'COVID-00026.jpg', 'COVID-19', 'fig1'], dtype='<U91'),
#  array(['COVID-00027', 'COVID-00027.jpg', 'COVID-19', 'fig1'], dtype='<U91'),
#  array(['COVID-00029', 'COVID-00029.jpg', 'COVID-19', 'fig1'], dtype='<U91'),
#  array(['COVID-00030', 'COVID-00030.jpg', 'COVID-19', 'fig1'], dtype='<U91'),
#  array(['COVID-00032', 'COVID-00032.jpg', 'COVID-19', 'fig1'], dtype='<U91'),
#  array(['COVID-00033', 'COVID-00033.jpg', 'COVID-19', 'fig1'], dtype='<U91'),
#  array(['COVID-00035', 'COVID-00035.jpg', 'COVID-19', 'fig1'], dtype='<U91'),
#  array(['COVID-00036', 'COVID-00036.jpg', 'COVID-19', 'fig1'], dtype='<U91'),
#  array(['COVID-00037', 'COVID-00037.jpg', 'COVID-19', 'fig1'], dtype='<U91'),
#  array(['COVID-00038', 'COVID-00038.jpg', 'COVID-19', 'fig1'], dtype='<U91'),
#  array(['ANON45',
#         'CR.1.2.840.113564.1722810170.20200320071047906500.1003000225002.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON234',
#         'CR.1.2.840.113564.1722810170.20200320072856343530.1003000225002.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON24',
#         'CR.1.2.840.113564.1722810170.20200320103403375580.1003000225002.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON220',
#         'CR.1.2.840.113564.1722810170.20200320183426328780.1003000225002.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON237',
#         'CR.1.2.840.113564.1722810170.20200321001546031810.1003000225002.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON218',
#         'CR.1.2.840.113564.1722810170.20200321002029359840.1003000225002.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON100',
#         'CR.1.2.840.113564.1722810170.20200321123520296900.1003000225002.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON174',
#         'CR.1.2.840.113564.1722810170.20200321172326140930.1003000225002.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON218',
#         'CR.1.2.840.113564.1722810170.202003211812003285.1003000225002.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON237',
#         'CR.1.2.840.113564.1722810170.20200322194859750610.1003000225002.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON191',
#         'CR.1.2.840.113564.1722810170.20200325010134750210.1003000225002.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON191',
#         'CR.1.2.840.113564.1722810170.20200325012424140230.1003000225002.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON126',
#         'CR.1.2.840.113564.1722810170.20200325212815187370.1003000225002.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON73',
#         'CR.1.2.840.113564.1722810170.20200329163846250860.1003000225002.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON73',
#         'CR.1.2.840.113564.1722810170.20200329171322703880.1003000225002.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON106',
#         'CR.1.2.840.113564.1722810170.20200330111806125940.1003000225002.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON44',
#         'CR.1.2.840.113564.1722810170.20200402113955515630.1003000225002.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON195',
#         'CR.1.2.840.113564.1722810170.20200403175115515840.1003000225002.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON29',
#         'CR.1.2.840.113564.1722810170.20200403211237078970.1003000225002.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON218',
#         'CR.1.2.840.113564.1722810170.202004040240155151.1003000225002.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON158',
#         'CR.1.2.840.113564.1722810170.20200407121512859570.1003000225002.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON201',
#         'CR.1.2.840.113564.1722810170.20200416020138312830.1003000225002.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON112',
#         'DX.1.2.840.113564.1722810162.20200322024635362290.1203801020003.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON19',
#         'DX.1.2.840.113564.1722810162.20200325130756972300.1203801020003.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON67',
#         'DX.1.2.840.113564.1722810162.20200326160333805210.1203801020003.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON30',
#         'DX.1.2.840.113564.1722810162.20200326172257446270.1203801020003.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON189',
#         'DX.1.2.840.113564.1722810162.20200328170109600900.1203801020003.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON110',
#         'DX.1.2.840.113564.1722810162.202003281918584533.1203801020003.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON153',
#         'DX.1.2.840.113564.1722810162.202004071718231126.1203801020003.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON240',
#         'DX.1.2.840.113564.1722810162.202004081114029075.1203801020003.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON53',
#         'DX.1.2.840.113564.1722810162.20200409093935803690.1203801020003.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON135',
#         'DX.1.2.840.113564.1722810162.20200409104802496810.1203801020003.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['ANON46',
#         'DX.1.2.840.113564.1722810162.20200415105839964650.1203801020003.png',
#         'COVID-19', 'actmed'], dtype='<U91'),
#  array(['COVID 70', 'COVID(70).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 72', 'COVID(72).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 77', 'COVID(77).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 81', 'COVID(81).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 87', 'COVID(87).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 94', 'COVID(94).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 95', 'COVID(95).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 106', 'COVID(106).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 107', 'COVID(107).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 116', 'COVID(116).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 119', 'COVID(119).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 129', 'COVID(129).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 131', 'COVID(131).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 213', 'COVID(213).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 214', 'COVID(214).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 215', 'COVID(215).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  array(['COVID 216', 'COVID(216).png', 'COVID-19', 'sirm'], dtype='<U91'),
#  ['46baab38-2341-4b1b-bd3c-fb16e4b1237f',
#   '46baab38-2341-4b1b-bd3c-fb16e4b1237f.png',
#   'normal',
#   'rsna'],
#  ['e8485b0f-293d-4ca8-8b71-92db61c8ee3e',
#   'e8485b0f-293d-4ca8-8b71-92db61c8ee3e.png',
#   'normal',
#   'rsna'],
#  ['3a5327d8-8830-4ae2-bd6b-293f5aa42d4b',
#   '3a5327d8-8830-4ae2-bd6b-293f5aa42d4b.png',
#   'normal',
#   'rsna'],
#  ['c392fefc-ec77-41d6-823e-b15e938661d0',
#   'c392fefc-ec77-41d6-823e-b15e938661d0.png',
#   'normal',
#   'rsna'],
#  ['f462597a-29bc-4693-b781-1f04036eba96',
#   'f462597a-29bc-4693-b781-1f04036eba96.png',
#   'normal',
#   'rsna'],
#  ['60dabf7b-68bb-46df-892a-7ceb8c14515f',
#   '60dabf7b-68bb-46df-892a-7ceb8c14515f.png',
#   'normal',
#   'rsna'],
#  ['ab9e97a4-c2a0-4ba9-a267-60205ef053f2',
#   'ab9e97a4-c2a0-4ba9-a267-60205ef053f2.png',
#   'normal',
#   'rsna'],
#  ['dc579b35-9ef1-4b75-93d6-e2412d5b33df',
#   'dc579b35-9ef1-4b75-93d6-e2412d5b33df.png',
#   'normal',
#   'rsna'],
#  ['f7ee1e68-4179-4703-a902-b35b8e2ccae7',
#   'f7ee1e68-4179-4703-a902-b35b8e2ccae7.png',
#   'normal',
#   'rsna'],
#  ['bca4aa4d-0cc9-4cc0-b06d-5b675194bf62',
#   'bca4aa4d-0cc9-4cc0-b06d-5b675194bf62.png',
#   'normal',
#   'rsna'],
#  ['3fc199bf-56c1-48fe-a00a-7592e3c00e3c',
#   '3fc199bf-56c1-48fe-a00a-7592e3c00e3c.png',
#   'pneumonia',
#   'rsna'],
#  ['a3476eba-8536-4271-a7a9-b13dc3cc8a4d',
#   'a3476eba-8536-4271-a7a9-b13dc3cc8a4d.png',
#   'pneumonia',
#   'rsna'],
#  ['349f10b4-dc3e-4f3f-b2e4-a5b81448ce87',
#   '349f10b4-dc3e-4f3f-b2e4-a5b81448ce87.png',
#   'pneumonia',
#   'rsna'],
#  ['2398ea30-8cf0-4265-b374-0300a5181759',
#   '2398ea30-8cf0-4265-b374-0300a5181759.png',
#   'pneumonia',
#   'rsna'],
#  ['aabc17eb-8303-4d12-9222-f2b2c07371e0',
#   'aabc17eb-8303-4d12-9222-f2b2c07371e0.png',
#   'pneumonia',
#   'rsna'],
#  ['c5d0608a-f8b0-4ac6-8dd7-56763aefd75e',
#   'c5d0608a-f8b0-4ac6-8dd7-56763aefd75e.png',
#   'pneumonia',
#   'rsna'],
#  ['1c44e0a4-4612-438f-9a83-8d5bf919cb67',
#   '1c44e0a4-4612-438f-9a83-8d5bf919cb67.png',
#   'pneumonia',
#   'rsna'],
#  ['34ba0b9f-640e-4e8d-9f60-3e6094cd3e50',
#   '34ba0b9f-640e-4e8d-9f60-3e6094cd3e50.png',
#   'pneumonia',
#   'rsna'],
#  ['ae50eb15-92f5-4a90-912c-20a8cc745be0',
#   'ae50eb15-92f5-4a90-912c-20a8cc745be0.png',
#   'pneumonia',
#   'rsna'],
#  ['bb7dca62-6180-4e52-81b6-8a9e09a4bfae',
#   'bb7dca62-6180-4e52-81b6-8a9e09a4bfae.png',
#   'pneumonia',
#   'rsna'],
#  ['a6236ddd-6367-4569-b5f1-07d2df9390ad',
#   'a6236ddd-6367-4569-b5f1-07d2df9390ad.png',
#   'pneumonia',
#   'rsna'],
#  ['5d2e858c-3188-44f7-b1f9-e70059dddff5',
#   '5d2e858c-3188-44f7-b1f9-e70059dddff5.png',
#   'pneumonia',
#   'rsna'],
#  ['0fd9d050-6ad7-4bd8-a18b-8e583192726f',
#   '0fd9d050-6ad7-4bd8-a18b-8e583192726f.png',
#   'pneumonia',
#   'rsna'],
#  ['cc118833-83a6-4f8f-ba7a-0e69faaaee72',
#   'cc118833-83a6-4f8f-ba7a-0e69faaaee72.png',
#   'pneumonia',
#   'rsna'],
#  ['bcdd92c8-2cde-4899-a6fc-46b875aaab62',
#   'bcdd92c8-2cde-4899-a6fc-46b875aaab62.png',
#   'pneumonia',
#   'rsna'],
#  ['f0ba0019-718f-4677-a723-05c27dba2f3e',
#   'f0ba0019-718f-4677-a723-05c27dba2f3e.png',
#   'pneumonia',
#   'rsna'],
#  ['8810a730-3f76-408d-ac9d-cef6e9629c89',
#   '8810a730-3f76-408d-ac9d-cef6e9629c89.png',
#   'pneumonia',
#   'rsna'],
#  ['17c15be0-a3be-49a4-a923-955ff5c962b2',
#   '17c15be0-a3be-49a4-a923-955ff5c962b2.png',
#   'pneumonia',
#   'rsna'],
#  ['0d15858e-bd96-42cf-843e-57ff0c6e42a7',
#   '0d15858e-bd96-42cf-843e-57ff0c6e42a7.png',
#   'pneumonia',
#   'rsna'],
#  ['06bc1519-c307-4a98-b00b-8329f2ddf615',
#   '06bc1519-c307-4a98-b00b-8329f2ddf615.png',
#   'pneumonia',
#   'rsna'],
#  ['34297b7d-9e22-4e73-b105-a8db72ad36ee',
#   '34297b7d-9e22-4e73-b105-a8db72ad36ee.png',
#   'pneumonia',
#   'rsna'],
#  ['b5714c0f-6d0f-4c56-833f-8b83f19e982a',
#   'b5714c0f-6d0f-4c56-833f-8b83f19e982a.png',
#   'pneumonia',
#   'rsna'],
#  array(['31',
#         'streptococcus-pneumoniae-pneumonia-temporal-evolution-1-day0.jpg',
#         'pneumonia', 'cohen'], dtype='<U64'),
#  ['dd4d6a4c-1e67-4911-bda2-7d8af75b1b19',
#   'dd4d6a4c-1e67-4911-bda2-7d8af75b1b19.png',
#   'pneumonia',
#   'rsna'],
#  ['ab81d5c0-1fba-49e5-93a8-fd4caee5f33c',
#   'ab81d5c0-1fba-49e5-93a8-fd4caee5f33c.png',
#   'pneumonia',
#   'rsna'],
#  ['8106073f-c91e-49cc-bfd8-c191fe793638',
#   '8106073f-c91e-49cc-bfd8-c191fe793638.png',
#   'pneumonia',
#   'rsna'],
#  ['a89eb468-2a15-4370-8725-70e8a1ff9007',
#   'a89eb468-2a15-4370-8725-70e8a1ff9007.png',
#   'pneumonia',
#   'rsna'],
#  ['17c3519c-2700-4357-87d4-94f0fb4f7bbe',
#   '17c3519c-2700-4357-87d4-94f0fb4f7bbe.png',
#   'pneumonia',
#   'rsna'],
#  ['5623a68b-8f2d-4295-bf4e-2f3a471cb84b',
#   '5623a68b-8f2d-4295-bf4e-2f3a471cb84b.png',
#   'pneumonia',
#   'rsna'],
#  ['22e76fb4-c74e-4cc3-820a-832a4467dac6',
#   '22e76fb4-c74e-4cc3-820a-832a4467dac6.png',
#   'pneumonia',
#   'rsna'],
#  ['70c1019f-e519-4bc3-9769-1344e65e3b38',
#   '70c1019f-e519-4bc3-9769-1344e65e3b38.png',
#   'pneumonia',
#   'rsna'],
#  ['7efc355d-92be-4776-8134-7c3daa100a00',
#   '7efc355d-92be-4776-8134-7c3daa100a00.png',
#   'pneumonia',
#   'rsna'],
#  ['3f504abe-2133-4e09-98af-743cdea486f9',
#   '3f504abe-2133-4e09-98af-743cdea486f9.png',
#   'pneumonia',
#   'rsna'],
#  ['ff0200e1-3bac-42d1-880b-17d6a3366d2c',
#   'ff0200e1-3bac-42d1-880b-17d6a3366d2c.png',
#   'pneumonia',
#   'rsna'],
#  ['bda266ca-cecd-4d88-a308-0c8a05dd8315',
#   'bda266ca-cecd-4d88-a308-0c8a05dd8315.png',
#   'pneumonia',
#   'rsna'],
#  ['3416e4ff-a8a4-4822-85ab-2e7e066457ba',
#   '3416e4ff-a8a4-4822-85ab-2e7e066457ba.png',
#   'pneumonia',
#   'rsna'],
#  ['3170c2b4-aa5a-4e6f-bf27-39ee0a2a416c',
#   '3170c2b4-aa5a-4e6f-bf27-39ee0a2a416c.png',
#   'pneumonia',
#   'rsna'],
#  ['a77b32f6-1999-4cc6-8a0d-1ef7e53850f0',
#   'a77b32f6-1999-4cc6-8a0d-1ef7e53850f0.png',
#   'pneumonia',
#   'rsna'],
#  ['eb17c134-0bf7-472a-96df-9253e86ceaa2',
#   'eb17c134-0bf7-472a-96df-9253e86ceaa2.png',
#   'pneumonia',
#   'rsna'],
#  ['db0018a5-7d08-4723-ac31-884bbb52910b',
#   'db0018a5-7d08-4723-ac31-884bbb52910b.png',
#   'pneumonia',
#   'rsna'],
#  ['376a6f4e-a470-48e7-9092-b6179f296e46',
#   '376a6f4e-a470-48e7-9092-b6179f296e46.png',
#   'pneumonia',
#   'rsna'],
#  ['a129ce0b-cd13-4625-b58c-5b5c5bf909f5',
#   'a129ce0b-cd13-4625-b58c-5b5c5bf909f5.png',
#   'pneumonia',
#   'rsna'],
#  ['0f639fad-780e-44f8-ba8d-0c934bdca870',
#   '0f639fad-780e-44f8-ba8d-0c934bdca870.png',
#   'pneumonia',
#   'rsna'],
#  ['97a91432-e516-425b-adf2-260b743f588c',
#   '97a91432-e516-425b-adf2-260b743f588c.png',
#   'pneumonia',
#   'rsna'],
#  ['3c4945ed-5abe-46b4-ad72-8377685fa14e',
#   '3c4945ed-5abe-46b4-ad72-8377685fa14e.png',
#   'pneumonia',
#   'rsna'],
#  ['0550968f-5ad7-460c-96c5-c2702535e344',
#   '0550968f-5ad7-460c-96c5-c2702535e344.png',
#   'pneumonia',
#   'rsna'],
#  ['ab150245-a188-4c66-9b84-e7dbf1f1c6cd',
#   'ab150245-a188-4c66-9b84-e7dbf1f1c6cd.png',
#   'pneumonia',
#   'rsna'],
#  ['fcd159f4-21d3-4169-a94b-95a2b5ccddcb',
#   'fcd159f4-21d3-4169-a94b-95a2b5ccddcb.png',
#   'pneumonia',
#   'rsna'],
#  ['5ca7b965-3241-4b44-b6cb-32ad06bcca84',
#   '5ca7b965-3241-4b44-b6cb-32ad06bcca84.png',
#   'pneumonia',
#   'rsna'],
#  ['94d022ae-b64e-4a83-a896-60749294d3d3',
#   '94d022ae-b64e-4a83-a896-60749294d3d3.png',
#   'pneumonia',
#   'rsna'],
#  ['bd25f8f0-311f-4373-af5f-25ad7e140344',
#   'bd25f8f0-311f-4373-af5f-25ad7e140344.png',
#   'pneumonia',
#   'rsna'],
#  ['b3cbe758-859f-4ace-8968-4953ca48dfc7',
#   'b3cbe758-859f-4ace-8968-4953ca48dfc7.png',
#   'pneumonia',
#   'rsna'],
#  ['a6c364d2-b2d6-4b0b-a439-40b992ff65c7',
#   'a6c364d2-b2d6-4b0b-a439-40b992ff65c7.png',
#   'pneumonia',
#   'rsna'],
#  ['2c917d3a-95cb-4c11-802c-f83e28cb37bc',
#   '2c917d3a-95cb-4c11-802c-f83e28cb37bc.png',
#   'pneumonia',
#   'rsna'],
#  ['808d5693-0d8a-4ed3-9407-1f842997e35f',
#   '808d5693-0d8a-4ed3-9407-1f842997e35f.png',
#   'pneumonia',
#   'rsna'],
#  ['96f34fa9-0e56-4fdb-bfd7-781d8c453bcb',
#   '96f34fa9-0e56-4fdb-bfd7-781d8c453bcb.png',
#   'pneumonia',
#   'rsna'],
#  ['515ab870-a80e-47f1-bd51-05a6fc02cba0',
#   '515ab870-a80e-47f1-bd51-05a6fc02cba0.png',
#   'pneumonia',
#   'rsna'],
#  ['55bf30ae-819a-4d20-816c-d45615df0688',
#   '55bf30ae-819a-4d20-816c-d45615df0688.png',
#   'pneumonia',
#   'rsna'],
#  ['55754887-a552-47dd-a5c6-2d069da40136',
#   '55754887-a552-47dd-a5c6-2d069da40136.png',
#   'pneumonia',
#   'rsna'],
#  ['0b7a4fb2-adab-484b-a0f7-23f5111bc745',
#   '0b7a4fb2-adab-484b-a0f7-23f5111bc745.png',
#   'pneumonia',
#   'rsna'],
#  ['cc0be168-3b95-4a71-9e74-e2cf577dfb4d',
#   'cc0be168-3b95-4a71-9e74-e2cf577dfb4d.png',
#   'pneumonia',
#   'rsna'],
#  ['1d9ec3ad-0120-428b-9778-3805f9348092',
#   '1d9ec3ad-0120-428b-9778-3805f9348092.png',
#   'pneumonia',
#   'rsna'],
#  ['3342938c-21d3-4f72-a0ce-9d930f4b98dc',
#   '3342938c-21d3-4f72-a0ce-9d930f4b98dc.png',
#   'pneumonia',
#   'rsna'],
#  ['3d643bc7-85ea-4684-88f6-4e2ee36ff46d',
#   '3d643bc7-85ea-4684-88f6-4e2ee36ff46d.png',
#   'pneumonia',
#   'rsna'],
#  ['41560731-6e3f-44b9-b951-e789bb8e0cc8',
#   '41560731-6e3f-44b9-b951-e789bb8e0cc8.png',
#   'pneumonia',
#   'rsna'],
#  ['0c4c0dd9-1685-48c3-a09e-817816695016',
#   '0c4c0dd9-1685-48c3-a09e-817816695016.png',
#   'pneumonia',
#   'rsna'],
#  ['b479635e-4c58-4d27-879b-fb0e87b2a1aa',
#   'b479635e-4c58-4d27-879b-fb0e87b2a1aa.png',
#   'pneumonia',
#   'rsna'],
#  ['f3d8b643-0706-4997-8819-92bb95524626',
#   'f3d8b643-0706-4997-8819-92bb95524626.png',
#   'pneumonia',
#   'rsna'],
#  ['8e64e543-299b-45b5-abfb-deee03fe9736',
#   '8e64e543-299b-45b5-abfb-deee03fe9736.png',
#   'pneumonia',
#   'rsna'],
#  ['f12d7b12-0398-4533-8f55-8772cc434945',
#   'f12d7b12-0398-4533-8f55-8772cc434945.png',
#   'pneumonia',
#   'rsna']]

# %%
final_test_data = [[]]

for sample in final_test:
    if len(sample) == 4:
        if sample[2] == "COVID-19":
            final_test_data.append([sample[1], 'positive'])
        else:
            final_test_data.append([sample[1], 'negative'])
    else:
        if sample[2] == "COVID-19":
            final_test_data.append(sample[1], 'positive')
        else:
            final_test_data.append([sample[1], 'negative'])

del final_test_data[0]

# %%
final_test_data
# Out:
# [['CR.1.2.840.113564.1722810170.20200418154808640220.1003000225002.png',
#   'negative'],
#  ['CR.1.2.840.113564.192168196.2020040610405214785.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200321192719071860.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200324090442116980.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200324173135171450.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200325035519587850.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200325235118699920.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200327135133580890.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.202003271502385806.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200328190915750960.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200402222138430240.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200403095438767300.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.202004031554257618.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200403173403510160.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200407205007081240.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200417111010040980.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200417170403543170.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200420091034687240.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.20200420124516732440.1203801020003.png',
#   'negative'],
#  ['DX.1.2.840.113564.1722810162.202004201905117341.1203801020003.png',
#   'negative'],
#  ['1-s2.0-S0929664620300449-gr2_lrg-a.jpg', 'positive'],
#  ['1-s2.0-S0929664620300449-gr2_lrg-b.jpg', 'positive'],
#  ['1-s2.0-S0929664620300449-gr2_lrg-c.jpg', 'positive'],
#  ['1-s2.0-S0929664620300449-gr2_lrg-d.jpg', 'positive'],
#  ['covid-19-pneumonia-15-PA.jpg', 'positive'],
#  ['8FDE8DBA-CFBD-4B4C-B1A4-6F36A93B7E87.jpeg', 'positive'],
#  ['9C34AF49-E589-44D5-92D3-168B3B04E4A6.jpeg', 'positive'],
#  ['1B734A89-A1BF-49A8-A1D3-66FAFA4FAC5D.jpeg', 'positive'],
#  ['B2D20576-00B7-4519-A415-72DE29C90C34.jpeg', 'positive'],
#  ['6C94A287-C059-46A0-8600-AFB95F4727B7.jpeg', 'positive'],
#  ['6b44464d-73a7-4cf3-bbb6-ffe7168300e3.annot.original.jpeg', 'positive'],
#  ['covid-19-rapidly-progressive-acute-respiratory-distress-syndrome-ards-admission.jpg',
#   'positive'],
#  ['covid-19-rapidly-progressive-acute-respiratory-distress-syndrome-ards-day-1.jpg',
#   'positive'],
#  ['covid-19-rapidly-progressive-acute-respiratory-distress-syndrome-ards-day-2.jpg',
#   'positive'],
#  ['covid-19-rapidly-progressive-acute-respiratory-distress-syndrome-ards-day-3.jpg',
#   'positive'],
#  ['covid-19-pneumonia-evolution-over-a-week-1-day0-PA.jpg', 'positive'],
#  ['covid-19-pneumonia-evolution-over-a-week-1-day3.jpg', 'positive'],
#  ['covid-19-pneumonia-evolution-over-a-week-1-day4.jpg', 'positive'],
#  ['covid-19-pneumonia-evolution-over-a-week-1-day6.jpg', 'positive'],
#  ['covid-19-pneumonia-23-day1.jpg', 'positive'],
#  ['covid-19-pneumonia-23-day3.jpg', 'positive'],
#  ['covid-19-pneumonia-23-day9.jpg', 'positive'],
#  ['RX-torace-a-letto-del-paziente-in-unica-proiezione-AP-1-1.jpeg',
#   'positive'],
#  ['covid-19-pneumonia-43-day0.jpeg', 'positive'],
#  ['covid-19-pneumonia-43-day2.jpeg', 'positive'],
#  ['figure1-5e7c1b8d98c29ab001275405-98.jpeg', 'positive'],
#  ['figure1-5e7c1b8d98c29ab001275405-98-later.jpeg', 'positive'],
#  ['covid-19-pneumonia-20-pa-on-admission.jpg', 'positive'],
#  ['covid-19-pneumonia-20.jpg', 'positive'],
#  ['covid-19-pneumonia-44-day-0.jpeg', 'positive'],
#  ['covid-19-pneumonia-44-day-8.jpeg', 'positive'],
#  ['covid-19-pneumonia-mild.JPG', 'positive'],
#  ['covid-19-pneumonia-67.jpeg', 'positive'],
#  ['16654_1_1.png', 'positive'],
#  ['16654_2_1.jpg', 'positive'],
#  ['16654_4_1.jpg', 'positive'],
#  ['88de9d8c39e946abd495b37cd07d89e5-0666-0.jpg', 'positive'],
#  ['88de9d8c39e946abd495b37cd07d89e5-2ee6-0.jpg', 'positive'],
#  ['88de9d8c39e946abd495b37cd07d89e5-6531-0.jpg', 'positive'],
#  ['COVID-00025.jpg', 'positive'],
#  ['COVID-00026.jpg', 'positive'],
#  ['COVID-00027.jpg', 'positive'],
#  ['COVID-00029.jpg', 'positive'],
#  ['COVID-00030.jpg', 'positive'],
#  ['COVID-00032.jpg', 'positive'],
#  ['COVID-00033.jpg', 'positive'],
#  ['COVID-00035.jpg', 'positive'],
#  ['COVID-00036.jpg', 'positive'],
#  ['COVID-00037.jpg', 'positive'],
#  ['COVID-00038.jpg', 'positive'],
#  ['CR.1.2.840.113564.1722810170.20200320071047906500.1003000225002.png',
#   'positive'],
#  ['CR.1.2.840.113564.1722810170.20200320072856343530.1003000225002.png',
#   'positive'],
#  ['CR.1.2.840.113564.1722810170.20200320103403375580.1003000225002.png',
#   'positive'],
#  ['CR.1.2.840.113564.1722810170.20200320183426328780.1003000225002.png',
#   'positive'],
#  ['CR.1.2.840.113564.1722810170.20200321001546031810.1003000225002.png',
#   'positive'],
#  ['CR.1.2.840.113564.1722810170.20200321002029359840.1003000225002.png',
#   'positive'],
#  ['CR.1.2.840.113564.1722810170.20200321123520296900.1003000225002.png',
#   'positive'],
#  ['CR.1.2.840.113564.1722810170.20200321172326140930.1003000225002.png',
#   'positive'],
#  ['CR.1.2.840.113564.1722810170.202003211812003285.1003000225002.png',
#   'positive'],
#  ['CR.1.2.840.113564.1722810170.20200322194859750610.1003000225002.png',
#   'positive'],
#  ['CR.1.2.840.113564.1722810170.20200325010134750210.1003000225002.png',
#   'positive'],
#  ['CR.1.2.840.113564.1722810170.20200325012424140230.1003000225002.png',
#   'positive'],
#  ['CR.1.2.840.113564.1722810170.20200325212815187370.1003000225002.png',
#   'positive'],
#  ['CR.1.2.840.113564.1722810170.20200329163846250860.1003000225002.png',
#   'positive'],
#  ['CR.1.2.840.113564.1722810170.20200329171322703880.1003000225002.png',
#   'positive'],
#  ['CR.1.2.840.113564.1722810170.20200330111806125940.1003000225002.png',
#   'positive'],
#  ['CR.1.2.840.113564.1722810170.20200402113955515630.1003000225002.png',
#   'positive'],
#  ['CR.1.2.840.113564.1722810170.20200403175115515840.1003000225002.png',
#   'positive'],
#  ['CR.1.2.840.113564.1722810170.20200403211237078970.1003000225002.png',
#   'positive'],
#  ['CR.1.2.840.113564.1722810170.202004040240155151.1003000225002.png',
#   'positive'],
#  ['CR.1.2.840.113564.1722810170.20200407121512859570.1003000225002.png',
#   'positive'],
#  ['CR.1.2.840.113564.1722810170.20200416020138312830.1003000225002.png',
#   'positive'],
#  ['DX.1.2.840.113564.1722810162.20200322024635362290.1203801020003.png',
#   'positive'],
#  ['DX.1.2.840.113564.1722810162.20200325130756972300.1203801020003.png',
#   'positive'],
#  ['DX.1.2.840.113564.1722810162.20200326160333805210.1203801020003.png',
#   'positive'],
#  ['DX.1.2.840.113564.1722810162.20200326172257446270.1203801020003.png',
#   'positive'],
#  ['DX.1.2.840.113564.1722810162.20200328170109600900.1203801020003.png',
#   'positive'],
#  ['DX.1.2.840.113564.1722810162.202003281918584533.1203801020003.png',
#   'positive'],
#  ['DX.1.2.840.113564.1722810162.202004071718231126.1203801020003.png',
#   'positive'],
#  ['DX.1.2.840.113564.1722810162.202004081114029075.1203801020003.png',
#   'positive'],
#  ['DX.1.2.840.113564.1722810162.20200409093935803690.1203801020003.png',
#   'positive'],
#  ['DX.1.2.840.113564.1722810162.20200409104802496810.1203801020003.png',
#   'positive'],
#  ['DX.1.2.840.113564.1722810162.20200415105839964650.1203801020003.png',
#   'positive'],
#  ['COVID(70).png', 'positive'],
#  ['COVID(72).png', 'positive'],
#  ['COVID(77).png', 'positive'],
#  ['COVID(81).png', 'positive'],
#  ['COVID(87).png', 'positive'],
#  ['COVID(94).png', 'positive'],
#  ['COVID(95).png', 'positive'],
#  ['COVID(106).png', 'positive'],
#  ['COVID(107).png', 'positive'],
#  ['COVID(116).png', 'positive'],
#  ['COVID(119).png', 'positive'],
#  ['COVID(129).png', 'positive'],
#  ['COVID(131).png', 'positive'],
#  ['COVID(213).png', 'positive'],
#  ['COVID(214).png', 'positive'],
#  ['COVID(215).png', 'positive'],
#  ['COVID(216).png', 'positive'],
#  ['46baab38-2341-4b1b-bd3c-fb16e4b1237f.png', 'negative'],
#  ['e8485b0f-293d-4ca8-8b71-92db61c8ee3e.png', 'negative'],
#  ['3a5327d8-8830-4ae2-bd6b-293f5aa42d4b.png', 'negative'],
#  ['c392fefc-ec77-41d6-823e-b15e938661d0.png', 'negative'],
#  ['f462597a-29bc-4693-b781-1f04036eba96.png', 'negative'],
#  ['60dabf7b-68bb-46df-892a-7ceb8c14515f.png', 'negative'],
#  ['ab9e97a4-c2a0-4ba9-a267-60205ef053f2.png', 'negative'],
#  ['dc579b35-9ef1-4b75-93d6-e2412d5b33df.png', 'negative'],
#  ['f7ee1e68-4179-4703-a902-b35b8e2ccae7.png', 'negative'],
#  ['bca4aa4d-0cc9-4cc0-b06d-5b675194bf62.png', 'negative'],
#  ['3fc199bf-56c1-48fe-a00a-7592e3c00e3c.png', 'negative'],
#  ['a3476eba-8536-4271-a7a9-b13dc3cc8a4d.png', 'negative'],
#  ['349f10b4-dc3e-4f3f-b2e4-a5b81448ce87.png', 'negative'],
#  ['2398ea30-8cf0-4265-b374-0300a5181759.png', 'negative'],
#  ['aabc17eb-8303-4d12-9222-f2b2c07371e0.png', 'negative'],
#  ['c5d0608a-f8b0-4ac6-8dd7-56763aefd75e.png', 'negative'],
#  ['1c44e0a4-4612-438f-9a83-8d5bf919cb67.png', 'negative'],
#  ['34ba0b9f-640e-4e8d-9f60-3e6094cd3e50.png', 'negative'],
#  ['ae50eb15-92f5-4a90-912c-20a8cc745be0.png', 'negative'],
#  ['bb7dca62-6180-4e52-81b6-8a9e09a4bfae.png', 'negative'],
#  ['a6236ddd-6367-4569-b5f1-07d2df9390ad.png', 'negative'],
#  ['5d2e858c-3188-44f7-b1f9-e70059dddff5.png', 'negative'],
#  ['0fd9d050-6ad7-4bd8-a18b-8e583192726f.png', 'negative'],
#  ['cc118833-83a6-4f8f-ba7a-0e69faaaee72.png', 'negative'],
#  ['bcdd92c8-2cde-4899-a6fc-46b875aaab62.png', 'negative'],
#  ['f0ba0019-718f-4677-a723-05c27dba2f3e.png', 'negative'],
#  ['8810a730-3f76-408d-ac9d-cef6e9629c89.png', 'negative'],
#  ['17c15be0-a3be-49a4-a923-955ff5c962b2.png', 'negative'],
#  ['0d15858e-bd96-42cf-843e-57ff0c6e42a7.png', 'negative'],
#  ['06bc1519-c307-4a98-b00b-8329f2ddf615.png', 'negative'],
#  ['34297b7d-9e22-4e73-b105-a8db72ad36ee.png', 'negative'],
#  ['b5714c0f-6d0f-4c56-833f-8b83f19e982a.png', 'negative'],
#  ['streptococcus-pneumoniae-pneumonia-temporal-evolution-1-day0.jpg',
#   'negative'],
#  ['dd4d6a4c-1e67-4911-bda2-7d8af75b1b19.png', 'negative'],
#  ['ab81d5c0-1fba-49e5-93a8-fd4caee5f33c.png', 'negative'],
#  ['8106073f-c91e-49cc-bfd8-c191fe793638.png', 'negative'],
#  ['a89eb468-2a15-4370-8725-70e8a1ff9007.png', 'negative'],
#  ['17c3519c-2700-4357-87d4-94f0fb4f7bbe.png', 'negative'],
#  ['5623a68b-8f2d-4295-bf4e-2f3a471cb84b.png', 'negative'],
#  ['22e76fb4-c74e-4cc3-820a-832a4467dac6.png', 'negative'],
#  ['70c1019f-e519-4bc3-9769-1344e65e3b38.png', 'negative'],
#  ['7efc355d-92be-4776-8134-7c3daa100a00.png', 'negative'],
#  ['3f504abe-2133-4e09-98af-743cdea486f9.png', 'negative'],
#  ['ff0200e1-3bac-42d1-880b-17d6a3366d2c.png', 'negative'],
#  ['bda266ca-cecd-4d88-a308-0c8a05dd8315.png', 'negative'],
#  ['3416e4ff-a8a4-4822-85ab-2e7e066457ba.png', 'negative'],
#  ['3170c2b4-aa5a-4e6f-bf27-39ee0a2a416c.png', 'negative'],
#  ['a77b32f6-1999-4cc6-8a0d-1ef7e53850f0.png', 'negative'],
#  ['eb17c134-0bf7-472a-96df-9253e86ceaa2.png', 'negative'],
#  ['db0018a5-7d08-4723-ac31-884bbb52910b.png', 'negative'],
#  ['376a6f4e-a470-48e7-9092-b6179f296e46.png', 'negative'],
#  ['a129ce0b-cd13-4625-b58c-5b5c5bf909f5.png', 'negative'],
#  ['0f639fad-780e-44f8-ba8d-0c934bdca870.png', 'negative'],
#  ['97a91432-e516-425b-adf2-260b743f588c.png', 'negative'],
#  ['3c4945ed-5abe-46b4-ad72-8377685fa14e.png', 'negative'],
#  ['0550968f-5ad7-460c-96c5-c2702535e344.png', 'negative'],
#  ['ab150245-a188-4c66-9b84-e7dbf1f1c6cd.png', 'negative'],
#  ['fcd159f4-21d3-4169-a94b-95a2b5ccddcb.png', 'negative'],
#  ['5ca7b965-3241-4b44-b6cb-32ad06bcca84.png', 'negative'],
#  ['94d022ae-b64e-4a83-a896-60749294d3d3.png', 'negative'],
#  ['bd25f8f0-311f-4373-af5f-25ad7e140344.png', 'negative'],
#  ['b3cbe758-859f-4ace-8968-4953ca48dfc7.png', 'negative'],
#  ['a6c364d2-b2d6-4b0b-a439-40b992ff65c7.png', 'negative'],
#  ['2c917d3a-95cb-4c11-802c-f83e28cb37bc.png', 'negative'],
#  ['808d5693-0d8a-4ed3-9407-1f842997e35f.png', 'negative'],
#  ['96f34fa9-0e56-4fdb-bfd7-781d8c453bcb.png', 'negative'],
#  ['515ab870-a80e-47f1-bd51-05a6fc02cba0.png', 'negative'],
#  ['55bf30ae-819a-4d20-816c-d45615df0688.png', 'negative'],
#  ['55754887-a552-47dd-a5c6-2d069da40136.png', 'negative'],
#  ['0b7a4fb2-adab-484b-a0f7-23f5111bc745.png', 'negative'],
#  ['cc0be168-3b95-4a71-9e74-e2cf577dfb4d.png', 'negative'],
#  ['1d9ec3ad-0120-428b-9778-3805f9348092.png', 'negative'],
#  ['3342938c-21d3-4f72-a0ce-9d930f4b98dc.png', 'negative'],
#  ['3d643bc7-85ea-4684-88f6-4e2ee36ff46d.png', 'negative'],
#  ['41560731-6e3f-44b9-b951-e789bb8e0cc8.png', 'negative'],
#  ['0c4c0dd9-1685-48c3-a09e-817816695016.png', 'negative'],
#  ['b479635e-4c58-4d27-879b-fb0e87b2a1aa.png', 'negative'],
#  ['f3d8b643-0706-4997-8819-92bb95524626.png', 'negative'],
#  ['8e64e543-299b-45b5-abfb-deee03fe9736.png', 'negative'],
#  ['f12d7b12-0398-4533-8f55-8772cc434945.png', 'negative']]

# %%
# opening the csv file in 'a+' mode 
file = open('test.csv', 'a+', newline ='') 
  
# writing the data into the file 
with file:     
    write = csv.writer(file) 
    write.writerows(final_test_data)

# %%
# export to train and test csv
# format as patientid, filename, label, separated by a space
# where label is either "positive" for COVID-19 or "negative" for anything else
train_file = open("train.csv",'w') 
for sample in train:
    if len(sample) == 4:
        if sample[2] == 'COVID-19':
            info = str(sample[1] + ' ' + 'positive'
        else:
            info = str(sample[1] + ' ' + 'negative'
    else:
        if sample[2] == 'COVID-19':
            info = str(sample[0]) + ' ' + sample[1] + ' ' + 'positive' + '\n'
        else:
            info = str(sample[0]) + ' ' + sample[1] + ' ' + 'negative' + '\n'
    train_file.write(info)

train_file.close()

test_file = open("test.csv", 'w')
for sample in final_test:
    if len(sample) == 4:
        if sample[2] == 'COVID-19':
            info = str(sample[0]) + ' ' + sample[1] + ' ' + 'positive' + ' ' + sample[3] + '\n'
        else:
            info = str(sample[0]) + ' ' + sample[1] + ' ' + 'negative' + ' ' + sample[3] + '\n'
    else:
        if sample[2] == 'COVID-19':
            info = str(sample[0]) + ' ' + sample[1] + ' ' + 'positive' + '\n'
        else:
            info = str(sample[0]) + ' ' + sample[1] + ' ' + 'negative' + '\n'
    test_file.write(info)

test_file.close()

# %%
positive_data = []
negative_data = []
for filename, classname in final_train_data:
    if classname == 'positive':
        positive_data.append(filename)
    elif classname == 'negative':
        negative_data.append(filename)

for item in positive_data:
    filename = os.path.basename(item)
    copyfile('data/train/' + item, os.path.join("data/positive/train", filename))

# %%
for item in negative_data:
    filename = os.path.basename(item)
    copyfile('data/train/' + item, os.path.join("data/negative/train", filename))

# %%
positive_data_test = []
negative_data_test = []
for filename, classname in final_test_data:
    if classname == 'positive':
        positive_data_test.append(filename)
    elif classname == 'negative':
        negative_data_test.append(filename)

for item in positive_data_test:
    filename = os.path.basename(item)
    copyfile('data/test/' + item, os.path.join("data/positive/test", filename))
    
for item in negative_data_test:
    filename = os.path.basename(item)
    copyfile('data/test/' + item, os.path.join("data/negative/test", filename))

# %%
len(test)
# Out:
# 1599
